# %%
r'''
PREREQS: 

    -DOWNLOAD https://github.com/mozilla/geckodriver/releases
          for selenium firefox web driver (default)
          Now set ENV_VAR by running below command in cmd/powershell:
          setx path "%path%;c:\Users\USERNAMEHERE\Downloads\geckodriver-v0.23.0-win64"
          
    -pip install mechanicalsoup
    
    -pip install selenium
    
    -pip install pyperclip
    
    ________________________________
    
    Example format for extraction:
    Count | Card Name | (Set# Card#)

    2 Trail Stories (Set1 #188)
    4 Horus Traver (Set1002 #23)
    4 Longbarrel (Set4 #5)
    4 On the Hunt (Set2 #5)
    4 Oni Dragonsmith (Set1003 #2)
'''
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
import json
import warnings
import mechanicalsoup
import pyperclip
warnings.filterwarnings(action='once')

# %% [markdown]
# # I: Login and extract collection fully from eternal warcry.

# %% [markdown]
# ## Note: Remove user/pass lane later!

# %%
"""
For those paying attention mechanize is python 2.x only, someone made mechanicalsoup
(Love you), which if you read the tutorial we give you a brief intro along with show you how
to login. This is compatible /w python 3.6. The code below takes in two command
line parameterse delimited by a space; username password.

ie: aggregate_card_json.py <username> <password>

For now I have my u+p information manually punched in and works!
"""

# import argparse
# parser = argparse.ArgumentParser(description="Login to EternalWarcry.")
# parser.add_argument("username")
# parser.add_argument("password")
# args = parser.parse_args()
user = '<user>'
passwd = '<pass>'

browser = mechanicalsoup.Browser(soup_config={'features': 'lxml'})

# request eternalWarcry login page. the result is a requests.Response object
login_page = browser.get("https://eternalwarcry.com/login")

# login_page.soup is a BeautifulSoup object

# we grab the login form
login_form = mechanicalsoup.Form(login_page.soup.select_one('form[action="/login"]'))

# specify username and password
login_form.input({"LoginEmail": user, "LoginPassword": passwd})# REPLACE WITH args.username & args.password
# submit form
page2 = browser.submit(login_form, login_page.url)
# Verify we logged in at Eternal Warcry...
print(page2.soup.title.text)

"""
STEP TWO: ITERATE THROUGH EACH PAGE AND GRAB ALL OF THE INFORMATION FOR EACH CARD,
PUT IT INTO A STRING IN THE PRETTY FORMAT THAT ETERNAL FOLLOWS, AND APPEND INTO A BIG LIST
OUTPUT WHICH IS YOUR COLLECTION FROM ETERNALWARCRY
(All this really does is save you time by not having to go into ->"Deck Builder" and
add ALL your cards to a deck and exporting it.... :))
"""
page_num = 1
check_last_pg = re.compile(r'\b(No cards found in your collection)\b')
final_collection = []

while True:
    # Now that were logged in pull each link for our collection and grab the info
    current_page = 'https://eternalwarcry.com/collection?view=oo&p=' + str(page_num)
    page_num = page_num + 1 # Iterate don't wanna forget ;)
    collection_page = browser.get(current_page) # Response object with .soup object
    
    # Get out of loop if we reach 'no cards exists' page.
    if bool(check_last_pg.search(collection_page.text)):
        break
    
    # Current Page. #collection_page.text because its response object
    html_page = collection_page.soup 
    # Get all cards on this page.
    divs = html_page.findAll(class_= 'card-search-item col-lg-3 col-sm-4 col-xs-6 add-card-main element-relative')  
    for div in divs:
        # This is where it gets fun. 
        # Each div is a card from the search_view. a href has the link which contains info.
        card_name = str(div.find_all('a'))
        #print(card_name) # This is to be searched for the name of card; can also acquire set and card#
        card_details = str(div.find(class_ = 'display-count'))

        # STEP TWO: FORMULATE CARD
        # First part of string is count
        count = str(re.search(r'data-count="(\d)"', card_details, re.IGNORECASE).group(1))

        # Now get set - card#
        card_set = str(re.search(r'data-card="(\d+-\d+)"', card_details, re.IGNORECASE).group(1))
        card_set = card_set.split('-')
        details = '(Set' + str(card_set[0]) + ' #' + str(card_set[1]) + ')'

        # Now get card name with grammar
        name = str(re.search(r'<img alt="(.+)" class=', card_name, re.IGNORECASE).group(1))

        # Put it altogether....
        item = count + ' ' + name + ' ' + details
        #print(item)

        # Drop each page into a list for later...
        final_collection.append(item)
        
        
# TODO: ADD SHIFSTONE AMOUNT TO MY_COLLECTION FOR BETTER ANALYSIS

# %%
len(final_collection) # Wow that numbers off! Eternal Statistics say I should have 68% 3,691/5,424 cards total.
# But let's think: IT's because it is only looking at the unique cards! So lets do math.

# %%
# Grab first character of each string (which we know is the count of each card in our collection up to 4) and add it.
total_cards = 0
for x in final_collection:
    total_cards = total_cards + int(x[0])
total_cards

output_json = {'total_cards': total_cards, 'my_collection': final_collection}

# %%
# Cool! WE got an accurate record of our cards, minus the Commons and UnCommons. Success for tonight.
# Output to a JSON file because sexy
with open('my_collection.json', 'w') as fp:
    json.dump(output_json, fp)

# %%
# Pull json back thru json file created above.
with open('my_collection.json', 'rb') as f:
    collection = json.load(f) #json with collection
collection # Show json object
# Out:
# {'total_cards': 3691,
#  'my_collection': ['4 Granite Monument (Set1 #423)',
#   '4 Granite Waystone (Set3 #1)',
#   '4 Shugo Standard (Set4 #1)',
#   '4 Helpful Doorbot (Set3 #2)',
#   '2 Trail Stories (Set1 #188)',
#   '4 Drifter (Set4 #2)',
#   '4 Feed the Flames (Set4 #3)',
#   '4 Firemane Cub (Set2 #1)',
#   '4 Forge Wolf (Set2 #2)',
#   '4 Grenadin Drone (Set1 #5)',
#   '4 Heavy Axe (Set1 #4)',
#   '4 Hidden Shiv (Set2 #4)',
#   '4 Iceberg Frontrunner (Set3 #3)',
#   "4 Kaleb's Intervention (Set3 #4)",
#   "4 Light 'em Up (Set4 #4)",
#   '4 Longbarrel (Set4 #5)',
#   '4 Mindfire (Set4 #6)',
#   '4 On the Hunt (Set2 #5)',
#   '4 Oni Dragonsmith (Set1003 #2)',
#   '4 Oni Ronin (Set1 #13)',
#   '4 Pummel (Set2 #6)',
#   '4 Pyroknight (Set1 #16)',
#   '4 Rambot (Set4 #7)',
#   '4 Ruin (Set1 #15)',
#   '4 Ruthless Stranger (Set1 #11)',
#   '4 Scrap Hound (Set3 #6)',
#   '4 Temper (Set1 #10)',
#   '4 Ticking Grenadin (Set1 #12)',
#   '4 Torch (Set1 #8)',
#   '4 Warhelm (Set1 #14)',
#   '4 Young Gun (Set2 #3)',
#   '4 Ankle Cutter (Set4 #8)',
#   '4 Bladekin Apprentice (Set1 #22)',
#   '4 Blazing Renegade (Set0 #4)',
#   '4 Blinkwolf (Set2 #7)',
#   '4 Consuming Flames (Set4 #9)',
#   '4 Disassembler (Set3 #8)',
#   '4 Flame Blast (Set1 #2)',
#   '3 Flamebelcher (Set4 #10)',
#   '4 Flamefang Charmer (Set4 #18)',
#   '4 Grenarender (Set4 #11)',
#   '4 Hotblood Barbarian (Set4 #12)',
#   '4 Into the Furnace (Set3 #9)',
#   "4 Kaleb's Favor (Set0 #3)",
#   '4 Oni Cavediver (Set3 #11)',
#   '4 Ornate Katana (Set1 #23)',
#   '4 Piercing Shot (Set1 #25)',
#   '4 Pyre Adept (Set1 #21)',
#   '1 Quicktrigger Outlaw (Set4 #13)',
#   '4 Rakano Outlaw (Set1 #20)',
#   '4 Rampage (Set1 #17)',
#   '4 Ruination Sledge (Set4 #14)',
#   "4 Smith's Hammer (Set2 #8)",
#   '4 Spark Hatcher (Set3 #12)',
#   '4 Trick Shot (Set4 #16)',
#   '4 Unpredictable Outlaw (Set3 #13)',
#   '1 Yeti Sage (Set3 #14)',
#   '4 Assembly Line (Set1 #29)',
#   "4 Backpacker's Machete (Set3 #15)",
#   '4 Censari Brigand (Set1 #34)',
#   '1 Factory Quota (Set4 #17)',
#   '4 Fevered Scout (Set1 #512)',
#   '4 First-Shot Rioter (Set3 #17)',
#   '4 Frontier Bard (Set4 #19)',
#   '4 Granite Acolyte (Set1 #31)',
#   '4 Granite Ring (Set2 #9)',
#   '4 Grenade (Set2 #10)',
#   '4 Hipshot (Set2 #11)',
#   '4 Hoof Slash (Set3 #18)',
#   '4 Ixtun Merchant (Set4 #21)',
#   '4 Jawbone Hatchet (Set2 #12)',
#   '4 Manufacture (Set4 #22)',
#   '4 Oni Eulogist (Set4 #23)',
#   '4 Oni Quartermaster (Set1 #32)',
#   '4 Rakano Flagbearer (Set1 #27)',
#   '4 Rally (Set1 #33)',
#   '4 Rebel Sharpshooter (Set1 #30)',
#   '4 Refracted Sentinel (Set4 #24)',
#   '4 Ruincrawler Yeti (Set3 #22)',
#   '4 Rusty Grenamotive (Set4 #26)',
#   "4 Shogun's Scepter (Set1 #26)",
#   '4 Skycrag Huntsman (Set3 #24)',
#   '4 Sparkbot (Set2 #13)',
#   '4 Stoneshaker (Set2 #15)',
#   '4 Temple Raider (Set3 #25)',
#   '4 Tumblebang (Set3 #27)',
#   '4 Twinbarrel (Set2 #16)',
#   '4 Warpainter (Set4 #27)',
#   "4 Won't Be Pretty (Set4 #28)",
#   '4 Ancient Defenses (Set3 #28)',
#   '4 Audacious Bandit (Set2 #17)',
#   '4 Barbarian Camp (Set3 #29)',
#   '4 Burn Out (Set1 #28)',
#   '4 Centaur Outrider (Set1 #35)',
#   '4 Clan Wallbreaker (Set4 #29)',
#   '4 Cloud of Ash (Set1 #39)',
#   '4 Crimson Firemaw (Set1002 #3)',
#   '4 Furnace Mage (Set1 #40)',
#   '4 Gravemarker Oni (Set4 #39)',
#   '4 Grenadin Cannoneer (Set2 #20)',
#   '4 Guerrilla Fighter (Set1 #36)',
#   '4 Hellfire Oni (Set3 #30)',
#   '4 Iceberg Scattershot (Set4 #32)',
#   '4 Magma Javelin (Set1 #41)',
#   '4 Morningstar (Set1 #510)',
#   '4 Outlands Brute (Set2 #18)',
#   '4 Outlands Sniper (Set1 #42)',
#   '4 Overheat (Set4 #34)',
#   '4 Rebel Illuminator (Set1 #43)',
#   '4 Recogulator (Set1 #37)',
#   '4 Reforge (Set2 #23)',
#   '4 Scalechannel Sorcerer (Set4 #35)',
#   '2 Steelfang Chakram (Set1 #38)',
#   '4 Stonescar Sawed-Off (Set3 #32)',
#   '4 Swift Stranger (Set2 #24)',
#   '4 Thunderhoof Warrior (Set2 #25)',
#   '4 Wandering Forge (Set3 #33)',
#   '4 Welding Torch (Set4 #36)',
#   '3 Yushkov, the Usurper (Set4 #310)',
#   '4 Bait (Set1001 #2)',
#   '4 Calderan Gunsmith (Set1 #46)',
#   '4 Centaur Raidleader (Set1 #50)',
#   '4 Dustblind (Set2 #19)',
#   '4 Dusthoof Brawler (Set1 #49)',
#   '4 Fiery Fissure (Set4 #38)',
#   '4 Flash Fire (Set0 #6)',
#   '4 Gun Down (Set2 #26)',
#   '2 Infernus (Set1 #45)',
#   '4 Oni Striker (Set1 #44)',
#   '4 Pit Fighter (Set2 #27)',
#   '4 Powderkeg Rider (Set3 #38)',
#   '4 Robobuddy (Set4 #40)',
#   '4 Staff of the Arch-Magister (Set3 #39)',
#   '4 Stonepowder Heretic (Set2 #29)',
#   '4 Wildfire Censari (Set4 #41)',
#   "4 Barkeep's Friend (Set3 #40)",
#   '4 Cannonbearer (Set2 #31)',
#   '4 Crowd Favorite (Set1 #58)',
#   '1 Dashing Rapscallion (Set4 #43)',
#   '1 End of the Barrel (Set4 #44)',
#   '4 Frontline Cyclops (Set1 #53)',
#   '4 Hellfire Rifle (Set1 #55)',
#   '4 Oni Gunwright (Set3 #42)',
#   '4 Pyre Elemental (Set4 #45)',
#   '4 Stonescar Maul (Set1 #52)',
#   '4 Tempered Sentinel (Set3 #45)',
#   '4 Burning Glaive (Set2 #33)',
#   '4 Core Scavenger (Set4 #46)',
#   '4 Final Shot (Set4 #47)',
#   '4 Improvised Rubbler (Set3 #47)',
#   '2 Steelbound Dragon (Set1 #60)',
#   '4 Heroic Bravo (Set3 #50)',
#   '1 Kaleb, Uncrowned Prince (Set1 #61)',
#   '4 Sindok, Rage Incarnate (Set2 #34)',
#   '4 Amber Monument (Set1 #420)',
#   '4 Amber Waystone (Set3 #51)',
#   '4 Temple Standard (Set4 #49)',
#   '4 Sand Warrior (Set1 #64)',
#   '4 Amaran Shoveler (Set3 #53)',
#   '4 Ancient Bauble (Set3 #54)',
#   '4 Cult Aspirant (Set2 #35)',
#   '4 Entrancer (Set4 #51)',
#   '4 Envelop (Set2 #36)',
#   '4 Excavate (Set1 #71)',
#   '4 Excavation Assistant (Set2 #37)',
#   '4 Gloaming Wisp (Set3 #55)',
#   '1 Hesitate (Set3 #56)',
#   '4 Humbug (Set1 #72)',
#   '4 Infinite Hourglass (Set1 #67)',
#   '4 Initiate of the Sands (Set1 #74)',
#   '4 Jibbering Jackal (Set4 #52)',
#   '4 Journey Guide (Set4 #53)',
#   '4 Lucky Prospector (Set3 #57)',
#   '4 Meditation (Set4 #54)',
#   '4 Ornamental Daggers (Set1 #69)',
#   '1 Pathlighter (Set4 #55)',
#   "4 Predator's Instinct (Set1 #75)",
#   '1 Randori (Set4 #56)',
#   '4 Sanctuary Priest (Set1 #73)',
#   '3 Sandstorm Scarf (Set4 #50)',
#   '4 Silence (Set0 #9)',
#   '4 Slow (Set1 #70)',
#   '4 Staff of Speed (Set4 #57)',
#   "4 Talir's Intervention (Set3 #58)",
#   '4 Training Ground (Set4 #59)',
#   '4 Water of Life (Set1 #68)',
#   '4 Accelerate (Set1 #85)',
#   '1 Accelerated Impact (Set3 #60)',
#   '3 Amaran Armadillo (Set4 #60)',
#   '4 Bold Adventurer (Set1 #77)',
#   '1 Copper Conduit (Set1 #66)',
#   '4 Cryptic Etchings (Set3 #62)',
#   '4 Disjunction (Set3 #63)',
#   '1 Ephemeral Wisp (Set1 #84)',
#   '1 Evelina, Valley Searcher (Set2 #48)',
#   '4 Find the Way (Set1 #513)',
#   '4 Friendly Wisp (Set1 #82)',
#   '4 Illumination Wisp (Set4 #61)',
#   '4 Last Rites (Set4 #62)',
#   '4 Learned Herbalist (Set4 #63)',
#   '4 Living Example (Set4 #64)',
#   '4 Living Offering (Set4 #65)',
#   '4 Nocturnal Creeper (Set3 #64)',
#   '4 Oasis Seeker (Set2 #41)',
#   '4 Refresh (Set1 #501)',
#   '4 Sand Viper (Set2 #42)',
#   '4 Sandglass Parma (Set4 #66)',
#   '4 Sandstorm (Set2 #43)',
#   '4 Sauropod Wrangler (Set1 #83)',
#   '4 Synchronized Strike (Set1 #88)',
#   "4 Talir's Favored (Set0 #11)",
#   '4 Teleport (Set1 #80)',
#   '4 Temple Scribe (Set1 #502)',
#   '4 Trail Maker (Set3 #65)',
#   '4 Trail Runner (Set2 #39)',
#   '4 Xenan Initiation (Set2 #44)',
#   '4 Ageless Mentor (Set1 #90)',
#   '4 Amaran Stinger (Set4 #68)',
#   '4 Amber Acolyte (Set1 #93)',
#   '4 Amber Ring (Set2 #45)',
#   '3 Arcanum Hourglass (Set4 #69)',
#   '4 Auralian Merchant (Set4 #70)',
#   '4 Avirax Familiar (Set2 #46)',
#   '4 Baying Serasaur (Set3 #66)',
#   '3 Clockroach (Set1 #94)',
#   '4 Decay (Set1 #95)',
#   '4 Deft Strike (Set4 #71)',
#   '4 Determined Stranger (Set1 #92)',
#   '1 Dig Site (Set3 #67)',
#   '4 Disciplined Amanera (Set2 #47)',
#   '4 Dispel (Set1 #91)',
#   '4 Dune Phantom (Set1 #89)',
#   '4 Gravetender (Set4 #72)',
#   '4 Initiation Bell (Set4 #73)',
#   '4 Lastlight Infusion (Set3 #68)',
#   '2 Lunar Magus (Set3 #69)',
#   '4 Moondial (Set3 #70)',
#   '4 Oasis Sanctuary (Set0 #15)',
#   '4 Premonition Wisp (Set3 #71)',
#   '4 Scorpion Wasp (Set1 #96)',
#   '4 Seasoned Spelunker (Set3 #72)',
#   '4 Secret Pages (Set1 #81)',
#   '4 Serene Excavator (Set3 #73)',
#   '4 Sirocco Elementalist (Set4 #74)',
#   '4 Spiteful Lumen (Set4 #84)',
#   '4 Unlock Potential (Set1 #76)',
#   '4 Watchful Amanera (Set4 #75)',
#   '1 Wurmcalling (Set4 #76)',
#   '4 Ageless Sentinel (Set3 #74)',
#   '4 Ancient Lore (Set1 #105)',
#   '4 Archive Curator (Set2 #50)',
#   '4 Bolster (Set2 #51)',
#   '4 Camp Physician (Set2 #52)',
#   '4 Devoted Theurge (Set1002 #6)',
#   '4 Fierce Mosaraptor (Set4 #77)',
#   '4 Gathering Lights (Set4 #78)',
#   "4 Healer's Cloak (Set1 #98)",
#   '4 Hissing Spiketail (Set3 #77)',
#   '4 Horned Vorlunk (Set1 #503)',
#   '1 Insatiable Serasaur (Set4 #80)',
#   '4 Insistent Automaton (Set3 #78)',
#   '4 Lost in the Mist (Set3 #79)',
#   '4 Lumen Attendant (Set4 #81)',
#   "1 Marisen's Disciple (Set1 #104)",
#   '4 Memento Mori (Set1003 #4)',
#   '4 Primeval Plover (Set4 #82)',
#   '4 Sandspout Mirage (Set4 #83)',
#   '1 Sandstorm Titan (Set1 #99)',
#   '4 Snapping Brushstalker (Set2 #53)',
#   '4 Stinging Wind (Set4 #85)',
#   '4 Striped Araktodon (Set2 #54)',
#   '4 Timekeeper (Set0 #14)',
#   '4 Towertop Patrol (Set1 #101)',
#   '4 Venom Rider (Set1003 #5)',
#   "4 Viper's Bite (Set2 #55)",
#   '4 Wurmstone (Set4 #86)',
#   '4 Xenan Guardian (Set1 #102)',
#   '1 Xenan Obelisk (Set1 #103)',
#   '4 Amaran Archaeologist (Set2 #56)',
#   '4 Awakened Sentinel (Set2 #57)',
#   '4 Battle-Tested Stranger (Set2 #58)',
#   '4 First Watch (Set3 #82)',
#   '4 Fishing Dinoch (Set3 #83)',
#   '4 Frenzied Omnivore (Set3 #84)',
#   '4 Lumen Defender (Set1 #115)',
#   '4 Mistress of Light (Set4 #92)',
#   '4 Pensive Lumen (Set4 #88)',
#   '4 Praxis Displacer (Set1 #100)',
#   '4 Sandbinder Sentinel (Set3 #85)',
#   '4 Time Weaver (Set2 #62)',
#   '4 Towering Terrazon (Set1 #114)',
#   '4 Twinbrood Sauropod (Set1 #113)',
#   '4 Vital Arcana (Set4 #89)',
#   '4 Wurmic Chanter (Set4 #90)',
#   '1 Divining Rod (Set1 #109)',
#   '4 Humbug Swarm (Set2 #60)',
#   '4 Lumen Shepherd (Set1 #117)',
#   '1 Mystic Ascendant (Set1 #116)',
#   '4 Pack Hunt (Set2 #61)',
#   '4 Panoptic Guardian (Set3 #89)',
#   '4 Passage of Eons (Set1001 #3)',
#   '4 Plated Goliath (Set2 #64)',
#   '4 Timeworn Sentinel (Set3 #90)',
#   '1 Tomb Protector (Set3 #91)',
#   '4 Voyaging Lumen (Set2 #66)',
#   '4 Dormant Sentinel (Set1 #120)',
#   '4 Elysian Pathfinder (Set1 #108)',
#   '1 Hall of Lost Kings (Set1 #121)',
#   '4 Hibernating Behemoth (Set1001 #4)',
#   '4 Pillar of Amar (Set1 #122)',
#   '1 Predatory Carnosaur (Set1 #118)',
#   '4 Reality Shift (Set4 #94)',
#   '4 Subterranean Sentry (Set4 #95)',
#   '4 Belching Behemoth (Set2 #68)',
#   '4 Intriguing Ancient (Set3 #95)',
#   '1 Talir, Who Sees Beyond (Set1 #124)',
#   '4 Scourstone Sentinel (Set3 #98)',
#   '4 Foraging Sauropod (Set3 #99)',
#   '4 Crownwatch Standard (Set4 #97)',
#   '4 Emerald Monument (Set1 #422)',
#   '4 Emerald Waystone (Set3 #101)',
#   '4 Harmless Question (Set4 #98)',
#   '4 Crownwatch Squire (Set2 #69)',
#   '4 Detain (Set1 #133)',
#   '4 District Infantry (Set1 #134)',
#   "4 Elder's Feather (Set1 #128)",
#   '4 Finest Hour (Set1 #130)',
#   '4 Humble Instructor (Set3 #103)',
#   '4 Ironfist Faithful (Set4 #99)',
#   '4 Lingering Influence (Set4 #100)',
#   '4 Minotaur Oathkeeper (Set2 #70)',
#   "4 Peacekeeper's Helm (Set4 #101)",
#   "4 Rolant's Intervention (Set3 #104)",
#   '4 Sharpened Reflex (Set4 #102)',
#   '4 Spire Spellsword (Set4 #103)',
#   '4 Steadfast Deputy (Set1 #504)',
#   '4 Steady Marshal (Set3 #105)',
#   '4 Tinker Apprentice (Set1 #131)',
#   '4 Valkyrie Aspirant (Set1 #127)',
#   '1 Whetstone (Set3 #107)',
#   '4 Arcane Defense (Set4 #104)',
#   '4 Argenport Soldier (Set1 #135)',
#   '1 Bar the Gates (Set4 #105)',
#   '4 Barricade (Set4 #106)',
#   '4 Copperhall Herald (Set2 #71)',
#   '4 Copperhall Porter (Set3 #108)',
#   '4 Crackshot Fugitive (Set3 #109)',
#   '4 Crownwatch Longsword (Set1 #142)',
#   '4 Crownwatch Paladin (Set1 #139)',
#   '4 Encouragement (Set4 #107)',
#   '4 Icaria, Valkyrie Captain (Set1003 #7)',
#   '4 Inspire (Set1 #129)',
#   '4 Master-at-Arms (Set4 #121)',
#   '4 Minotaur Grunt (Set1 #137)',
#   '3 Paladin Oathbook (Set1 #140)',
#   '4 Protect (Set1 #132)',
#   '4 Rampart Protector (Set3 #111)',
#   '4 Rebuke (Set1 #141)',
#   '4 Reinforce (Set1 #136)',
#   '4 Reinvigorate (Set3 #112)',
#   "4 Rilgon's Disciple (Set4 #110)",
#   "4 Rolant's Favor (Set0 #18)",
#   '4 Shamebearer (Set4 #111)',
#   '4 Soaring Guard (Set3 #102)',
#   '4 Sparring Partner (Set2 #77)',
#   '4 Stalwart Silverwing (Set2 #72)',
#   '4 Strength of Many (Set2 #73)',
#   '4 Talon of Nostrix (Set2 #74)',
#   '4 Tinker (Set2 #75)',
#   '4 Tranquil Scholar (Set2 #76)',
#   '4 Vanquish (Set1 #143)',
#   "4 Vanquisher's Blade (Set4 #112)",
#   '4 Wanted Poster (Set3 #106)',
#   '4 Workshop Tinker (Set4 #113)',
#   '4 Auric Herdward (Set4 #114)',
#   '4 Auric Sentry (Set1 #146)',
#   '4 Brightmace Paladin (Set1 #147)',
#   '4 Copperhall Bailiff (Set1001 #5)',
#   '4 Copperhall Cudgel (Set2 #78)',
#   '4 Copperhall Marshal (Set3 #114)',
#   '4 Copperhall Shieldman (Set2 #79)',
#   '4 Crownwatch Legionnaire (Set3 #115)',
#   '4 Emerald Acolyte (Set1 #153)',
#   '4 Emerald Ring (Set2 #80)',
#   '4 Fencing Master (Set2 #81)',
#   '4 Gilded Glaive (Set1 #125)',
#   '4 Grit (Set4 #116)',
#   '4 Guard Dog (Set4 #117)',
#   '4 Herald of the Parliament (Set4 #118)',
#   '4 Hero of the People (Set1 #156)',
#   '4 Highbranch Sentry (Set2 #82)',
#   '2 Hooru Envoy (Set1 #155)',
#   '4 Kosul Battlemage (Set4 #119)',
#   '4 Longhorn Treasurer (Set4 #120)',
#   '4 Loyal Watchwing (Set1 #150)',
#   '4 Mark of Shame (Set1 #165)',
#   "4 Miner's Canary (Set4 #109)",
#   '4 Privilege of Rank (Set1 #157)',
#   '4 Reinforced Baton (Set4 #122)',
#   '4 Saddle Up (Set4 #124)',
#   '4 Showdown (Set3 #117)',
#   '4 Signal Flag (Set3 #118)',
#   '4 Silverwing Familiar (Set1 #152)',
#   '4 Silverwing Smith (Set3 #119)',
#   '1 Spirit Guide (Set2 #83)',
#   '4 Tandem Watchwing (Set3 #121)',
#   '4 Tireless Stranger (Set2 #84)',
#   '4 Treasury Guard (Set1 #505)',
#   '4 Unseen Commando (Set3 #122)',
#   '4 Valkyrie Cadet (Set3 #123)',
#   '4 Valkyrie Enforcer (Set1 #151)',
#   '4 Valorous Stranger (Set1 #145)',
#   '4 Warrant Officer (Set4 #125)',
#   '1 Winchest Merchant (Set4 #126)',
#   '4 Armorsmith (Set1 #163)',
#   '1 Auric Runehammer (Set1 #166)',
#   '4 Bronze Cuirass (Set1 #148)',
#   '2 Citywide Ban (Set4 #127)',
#   '1 Copperhall Blessing (Set1 #168)',
#   '4 Copperhall Paladin (Set1002 #7)',
#   '4 Copperhall Recruit (Set1 #158)',
#   '4 Crownwatch Cavalry (Set1 #169)',
#   '4 Curse of Taxation (Set3 #127)',
#   '4 Entrapment (Set3 #116)',
#   '4 Frontier Confessor (Set3 #137)',
#   '4 Graceful Calligrapher (Set4 #129)',
#   '4 Ground Crew (Set3 #128)',
#   '4 Honor the Fallen (Set1003 #8)',
#   '4 Ironclad Oath (Set3 #129)',
#   '4 Mantle of Justice (Set0 #21)',
#   "2 Peacekeeper's Prod (Set2 #86)",
#   '4 Rabblerouser (Set2 #87)',
#   '4 Resolute Paladin (Set4 #130)',
#   "4 Sheriff's Hat (Set4 #132)",
#   '4 Shielded Shortbarrel (Set3 #132)',
#   '4 Silverwing Avenger (Set1 #167)',
#   '4 Sky Crew (Set4 #133)',
#   '4 Spiked Buckler (Set2 #88)',
#   '4 Spiritblade Stalker (Set3 #134)',
#   '4 Stalwart Shield (Set1 #162)',
#   '4 Valkyrie Bodyguard (Set3 #135)',
#   '4 Valkyrie Militant (Set2 #89)',
#   '2 Valkyrie Spireguard (Set2 #90)',
#   "4 Victor's Cry (Set2 #91)",
#   '4 Combrei Magister (Set1 #160)',
#   '4 Crownwatch Recruiter (Set4 #134)',
#   '4 Downfall (Set4 #135)',
#   '4 Harsh Rule (Set1 #172)',
#   '4 Hooru Fledgling (Set1 #159)',
#   '4 Minotaur Duelist (Set2 #93)',
#   '4 Mithril Mace (Set1 #171)',
#   '4 Rampart Arbalest (Set4 #136)',
#   '4 Scepter of Nobility (Set2 #94)',
#   '1 Silverwing Commander (Set1 #175)',
#   '4 Throne Warden (Set1 #514)',
#   '4 Twinstrike Master (Set1002 #8)',
#   "4 Aerialist's Khopesh (Set2 #95)",
#   '1 Augmented Form (Set1 #182)',
#   '4 Ceremonial Mask (Set1 #178)',
#   '4 Civic Peacekeeper (Set1 #180)',
#   '1 End of the Story (Set4 #138)',
#   '4 Fourth-Tree Elder (Set1 #176)',
#   '4 Heirloom Blade (Set4 #139)',
#   '4 Horngrinder (Set2 #96)',
#   '1 Ironfist Archon (Set4 #140)',
#   '4 Prosecutor-at-Arms (Set2 #97)',
#   '4 Roosting Owl (Set2 #99)',
#   '4 Silverwing Purgeleader (Set4 #141)',
#   '4 Tower Shield (Set3 #144)',
#   '4 Town Watchman (Set3 #145)',
#   '4 Valkyrie Arcanist (Set3 #139)',
#   '4 Watchwing Conscript (Set1002 #9)',
#   '4 Emerald Spear (Set3 #142)',
#   '4 Flight Lieutenant (Set1 #184)',
#   "1 Rolant's Honor Guard (Set1 #183)",
#   '4 Silverwing Augmentor (Set4 #142)',
#   '1 Rolant, the Iron Fist (Set1 #185)',
#   '4 Valkyrie Linebreaker (Set2 #102)',
#   '4 Silverwing Rallier (Set3 #150)',
#   '4 Clan Standard (Set4 #145)',
#   '4 Cobalt Monument (Set1 #418)',
#   '4 Cobalt Waystone (Set3 #151)',
#   '4 Blind Storyteller (Set1 #192)',
#   '4 Cloudsnake Hatchling (Set2 #103)',
#   "4 Eilyn's Intervention (Set3 #152)",
#   '4 Farplace Finder (Set3 #153)',
#   '4 Gift of Battle (Set4 #146)',
#   '4 Hearty Stranger (Set2 #104)',
#   '4 Jump Kick (Set3 #154)',
#   '4 Permafrost (Set1 #193)',
#   '4 Savage Denial (Set4 #147)',
#   '4 Savage Skybrood (Set3 #156)',
#   '4 Shiver (Set4 #148)',
#   '4 Sinister Opportunist (Set3 #157)',
#   '1 Snow Pelting (Set3 #158)',
#   '4 Snowcrust Yeti (Set2 #105)',
#   '4 Snowrager (Set4 #149)',
#   '4 Substitute (Set4 #150)',
#   '4 Unstable Form (Set1 #189)',
#   '4 Weather the Storm (Set2 #106)',
#   '4 Yeti Spy (Set1 #191)',
#   '4 Backlash (Set1 #200)',
#   '4 Borderlands Waykeeper (Set1 #517)',
#   '4 Campfire Watchman (Set4 #151)',
#   '4 Changeestik (Set4 #152)',
#   '4 Cloudsnake Breeder (Set2 #107)',
#   '1 Cloudsnake Saddle (Set1 #199)',
#   '4 Darkbolt (Set3 #159)',
#   '4 Dragonbreath (Set2 #108)',
#   '4 Dusk Raider (Set4 #153)',
#   '4 East-Wind Herald (Set1 #201)',
#   "4 Eilyn's Favor (Set0 #24)",
#   '4 Entangling Vines (Set4 #167)',
#   '4 Fearless Yeti (Set3 #161)',
#   '4 Gruanform (Set4 #154)',
#   "4 Herald's Song (Set1 #196)",
#   '2 Honored Skyguard (Set4 #155)',
#   '4 Horizon Seeker (Set3 #162)',
#   '4 Huddle Together (Set4 #156)',
#   '4 Iceberg Hailshrieker (Set4 #157)',
#   '4 Levitate (Set1 #190)',
#   '4 Lightning Storm (Set1 #206)',
#   '4 Lightning Strike (Set1 #197)',
#   '1 Maelstrom Bell (Set2 #109)',
#   '4 Portent Reader (Set4 #159)',
#   '4 Read the Stars (Set4 #160)',
#   '4 Scaly Gruan (Set1 #215)',
#   '4 Second Sight (Set1 #207)',
#   '4 Snowfort Trumpeter (Set4 #161)',
#   '4 Static Bolt (Set1 #194)',
#   '4 Storm Talisman (Set3 #164)',
#   '4 Strategize (Set3 #165)',
#   '4 Talon Dive (Set2 #112)',
#   '4 Tend the Flock (Set4 #162)',
#   '4 Torrential Downpour (Set4 #163)',
#   '4 Trailblaze (Set2 #111)',
#   '4 Twilight Hermit (Set3 #166)',
#   '4 Unseal (Set3 #167)',
#   '4 Violent Gust (Set1 #205)',
#   '1 Whispering Wind (Set1 #202)',
#   '4 Wild Cloudsnake (Set1 #195)',
#   "4 Winter's Grasp (Set3 #168)",
#   '4 Yeti Snowchucker (Set2 #113)',
#   '4 Yeti Snowslinger (Set1 #203)',
#   '4 Yeti Windflyer (Set3 #169)',
#   '4 Acquisitive Crow (Set4 #164)',
#   '4 Advance Scout (Set4 #165)',
#   '1 Cloudsnake Harrier (Set2 #114)',
#   '4 Cobalt Acolyte (Set1 #212)',
#   '4 Cobalt Ring (Set2 #115)',
#   '4 Crafty Yeti (Set2 #116)',
#   '1 Daring Pioneer (Set3 #170)',
#   '4 Electropy (Set3 #171)',
#   '4 Flash Freeze (Set1 #209)',
#   '4 Foothills Alpha (Set2 #117)',
#   '4 Hailstorm (Set1003 #11)',
#   '4 Ice Sprite (Set1 #214)',
#   '4 Icebow (Set2 #118)',
#   '4 Icebreaker (Set1 #216)',
#   '4 Jennev Merchant (Set4 #169)',
#   '4 Lethrai Darkstalker (Set4 #170)',
#   '4 Lethrai Secretweaver (Set4 #171)',
#   '4 Mirror Image (Set1 #217)',
#   '1 Nocturnal Observer (Set3 #173)',
#   '4 Polymorph (Set1 #211)',
#   '4 Rabid Yeti (Set4 #172)',
#   '4 Skyrider Vanguard (Set2 #120)',
#   '4 Skysnapper (Set1 #208)',
#   '4 Snowfort (Set3 #174)',
#   '4 South-Wind Herald (Set1002 #10)',
#   '4 Stormcrasher (Set2 #121)',
#   '3 Temple Shihan (Set4 #173)',
#   '4 Thunderbird (Set0 #27)',
#   '4 Tundra Explorer (Set1 #204)',
#   '4 Voracious Fosora (Set3 #176)',
#   '4 Wild Rider (Set3 #177)',
#   '4 Wisdom of the Elders (Set1 #218)',
#   '2 Yeti Furflinger (Set3 #178)',
#   '1 Breeze Dancer (Set4 #174)',
#   '4 Cutbrush Cartographer (Set3 #180)',
#   '4 Freewing Glider (Set3 #181)',
#   '4 Galeprowler (Set4 #175)',
#   '4 Icespear Chucker (Set4 #176)',
#   "4 Jarrall's Frostkin (Set1 #220)",
#   '4 Jotun Cyclops (Set2 #122)',
#   '4 Meditation Trainer (Set3 #182)',
#   '4 Nocturnal Kyrex (Set3 #183)',
#   '1 Regression (Set3 #184)',
#   '4 Resurface (Set4 #177)',
#   '4 Ridgeline Watcher (Set2 #123)',
#   '4 Scavenging Spikeback (Set4 #178)',
#   '4 Serpent Mount (Set2 #124)',
#   '4 Serpent Trainer (Set1 #219)',
#   '4 Slushdumper (Set3 #185)',
#   '4 Soaring Stranger (Set1 #229)',
#   '2 Spiritward Shaman (Set4 #179)',
#   '4 Stormcaller (Set1 #224)',
#   '4 Tyrannize (Set1001 #8)',
#   '4 Windshaper (Set1 #230)',
#   '4 Yeti Troublemaker (Set1 #222)',
#   '4 Yetipult (Set1002 #11)',
#   '4 Aerial Ace (Set1 #235)',
#   "4 Aeva, Eilyn's Elite (Set4 #180)",
#   '4 Cliffside Caretaker (Set4 #186)',
#   '2 Crystallize (Set1 #232)',
#   '4 First-Frost Shaman (Set4 #182)',
#   '2 Gleaming Shield (Set4 #183)',
#   '1 Jotun Feast-Caller (Set3 #187)',
#   '4 Jotun Hurler (Set1 #227)',
#   '4 Jotun Punter (Set3 #188)',
#   '4 Jotun Warrior (Set1 #226)',
#   '4 Primal Incarnation (Set0 #30)',
#   '4 Psionic Savant (Set1 #360)',
#   '4 Skycrag Wyvarch (Set1 #247)',
#   '4 Skywalk Instructor (Set2 #128)',
#   '1 Staff of Stories (Set1 #234)',
#   '4 Stampede Driver (Set3 #190)',
#   '4 Swindle (Set2 #129)',
#   '1 West-Wind Herald (Set1 #231)',
#   '4 Boltcrafter Shaman (Set2 #131)',
#   '1 Celestial Omen (Set1 #241)',
#   "4 Cirso's Meddling (Set2 #132)",
#   '4 Daraka, Queensguard (Set1003 #12)',
#   "1 Eilyn's Frostrider (Set3 #193)",
#   '1 Hatchery Hunter (Set1 #237)',
#   '4 Iceknuckle Jotun (Set2 #133)',
#   '4 Lumbering Gruan (Set2 #134)',
#   '4 Moonlight Huntress (Set4 #188)',
#   '4 North-Wind Herald (Set1 #240)',
#   '4 Sapphire Dragon (Set1 #236)',
#   '4 Shamanic Blast (Set4 #189)',
#   '4 Slope Sergeant (Set3 #195)',
#   '4 Speardiver (Set4 #185)',
#   '2 Thunderstrike Dragon (Set1 #243)',
#   '4 Adaptive Predator (Set2 #135)',
#   '4 Araktodon (Set1 #238)',
#   '4 Bellowing Thunderfoot (Set3 #198)',
#   '4 Elysian Trailblazer (Set1 #228)',
#   '4 Enraged Araktodon (Set4 #190)',
#   '4 Hooru Teachings (Set1002 #12)',
#   '4 Icequake (Set2 #136)',
#   '1 Kenna, Shaman of the Scale (Set4 #191)',
#   '1 Mistveil Drake (Set1 #242)',
#   '1 Eilyn, Queen of the Wilds (Set1 #245)',
#   '4 Surveying Mantasaur (Set3 #199)',
#   '3 Thunder Giant (Set4 #192)',
#   '1 Channel the Tempest (Set1 #244)',
#   '4 Amethyst Monument (Set1 #426)',
#   '4 Amethyst Waystone (Set3 #201)',
#   '4 Cabal Standard (Set4 #193)',
#   '4 Affliction (Set3 #202)',
#   '4 Arachnophobia (Set3 #203)',
#   '4 Blood Beetle (Set1 #260)',
#   '4 Brash Shorthorn (Set2 #137)',
#   '4 Dark Return (Set1 #250)',
#   '4 Direfang Spider (Set1 #256)',
#   '4 Fallen Oni (Set2 #138)',
#   '4 Feral Spiteling (Set4 #205)',
#   '4 Ghostform (Set1 #258)',
#   '4 Grenamender (Set3 #204)',
#   "4 Harbinger's Bite (Set4 #194)",
#   '4 Horrifying Helm (Set4 #195)',
#   "4 Jack's Knife (Set2 #139)",
#   '4 Knifejack (Set1 #257)',
#   '4 Lock Horns (Set4 #207)',
#   '4 Pilfer (Set1 #254)',
#   '4 Sabotage (Set1 #252)',
#   '4 Sewer Sludge (Set4 #196)',
#   '4 Slumbering Stone (Set1 #255)',
#   '4 Spitefeeder (Set4 #197)',
#   '4 Suffocate (Set1 #251)',
#   '4 Swear Vengeance (Set2 #140)',
#   '4 Tock Tick (Set2 #141)',
#   '4 Trusty Revolver (Set3 #206)',
#   "4 Vara's Intervention (Set3 #207)",
#   '4 Wisplight (Set3 #208)',
#   '4 Xenan Lifespeaker (Set4 #198)',
#   '4 Abduct (Set4 #199)',
#   '4 Afterimage (Set4 #212)',
#   '4 Annihilate (Set1 #269)',
#   '4 Back-Alley Delinquent (Set4 #200)',
#   '4 Battlefield Scavenger (Set3 #209)',
#   '4 Cabal Cutthroat (Set1 #297)',
#   '4 Cabal Slasher (Set2 #147)',
#   '4 Cowardice (Set3 #211)',
#   '4 Cull the Deck (Set4 #202)',
#   '4 Dark Wisp (Set1 #264)',
#   '4 Devour (Set1 #261)',
#   '2 Dreamsnatcher (Set3 #212)',
#   '1 Fenris Nightshade (Set4 #204)',
#   '4 Flashy Duelist (Set3 #213)',
#   '4 Grenadin Bellower (Set3 #214)',
#   '4 Infused Strike (Set3 #216)',
#   '4 Lethrai Ranger (Set1 #270)',
#   '4 Lethrai Target Caller (Set4 #206)',
#   '4 Longshot Marksman (Set2 #142)',
#   '4 Lunging Wisp (Set4 #208)',
#   '4 Magenta Wisp (Set4 #209)',
#   '1 Miris Nightshade (Set3 #217)',
#   '4 Piercing Grief (Set2 #143)',
#   '4 Rapid Shot (Set1 #259)',
#   '4 Scare (Set2 #144)',
#   '4 Scavenging Vulture (Set1 #265)',
#   '4 Sleeping Draught (Set3 #218)',
#   '4 Sporefolk (Set1 #262)',
#   '4 Territorial Elf (Set4 #210)',
#   "2 Thief's Pick (Set4 #211)",
#   '4 Threaten (Set2 #145)',
#   '4 Unseen Agent (Set3 #219)',
#   '4 Vampire Bat (Set0 #33)',
#   "4 Vara's Favor (Set0 #35)",
#   '4 Venomfang Dagger (Set1 #263)',
#   '4 Amethyst Acolyte (Set1 #276)',
#   '4 Amethyst Ring (Set2 #146)',
#   '4 Auric Interrogator (Set1002 #13)',
#   '4 Banished Umbren (Set4 #213)',
#   "4 Beastcaller's Amulet (Set1 #282)",
#   '4 Blackguard Sidearm (Set1 #266)',
#   '4 Coronal Umbren (Set4 #214)',
#   '4 Daggerclaw Howler (Set4 #215)',
#   '4 Desperado (Set1 #273)',
#   '4 Devouring Shadow (Set0 #36)',
#   '4 Direwood Beastcaller (Set1 #271)',
#   '4 Duskcaller (Set3 #222)',
#   '4 Execute (Set1 #277)',
#   '4 Extract (Set2 #155)',
#   '4 Hair-Trigger Pistol (Set4 #216)',
#   '4 Kerendon Merchant (Set4 #217)',
#   '4 Lethrai Memory-Keeper (Set2 #149)',
#   '4 Lethrai Nightblade (Set1 #279)',
#   '4 Lifedrinker (Set1 #275)',
#   '4 Madness (Set1 #267)',
#   '4 Maimed Watchwing (Set3 #223)',
#   '1 Marionette Cross (Set4 #218)',
#   '4 Plague (Set1 #274)',
#   '4 Prickly Grenadin (Set3 #224)',
#   '4 Ravenous Thornbeast (Set1 #278)',
#   '4 Scheme (Set1 #213)',
#   '2 Shadowlands Guide (Set1 #280)',
#   '4 Shadowstalker (Set4 #230)',
#   '4 Skeeter (Set2 #150)',
#   "4 Sorrow's Shroud (Set2 #151)",
#   '4 Sporebreath (Set4 #219)',
#   '4 Spur On (Set2 #152)',
#   "4 Surgeon's Saw (Set4 #220)",
#   '4 Trigger-Happy (Set2 #153)',
#   '4 Umbren Deathwatcher (Set4 #221)',
#   '4 Xenan Cultist (Set1 #516)',
#   '4 Xenan Destroyer (Set1 #281)',
#   '4 Argenport Sewers (Set1003 #14)',
#   '4 Back-Alley Bouncer (Set1 #284)',
#   '4 Betray the Cause (Set4 #234)',
#   '1 Burglarize (Set4 #224)',
#   '4 Cabal Bludgeoner (Set2 #156)',
#   '4 Cabal Recruiter (Set1 #283)',
#   '4 Corrupted Umbren (Set4 #225)',
#   '4 Cripple (Set2 #157)',
#   '4 Deathstrike (Set1 #290)',
#   '1 Devious Drone (Set3 #227)',
#   '4 Extinguish (Set3 #228)',
#   '4 Final-Shot Rioter (Set3 #229)',
#   '4 Holdup (Set4 #226)',
#   '1 Impending Doom (Set1 #286)',
#   '4 In Cold Blood (Set1003 #15)',
#   '4 Kyrex Coach Driver (Set4 #227)',
#   '2 Lethrai Falchion (Set1 #285)',
#   '1 Lethrai Provocateur (Set4 #228)',
#   '2 Memory Dredger (Set2 #159)',
#   '4 Minotaur Lighthoof (Set2 #163)',
#   '1 Relentless Gorehorn (Set2 #160)',
#   '4 Savage Stranger (Set2 #161)',
#   '4 Soul Collector (Set1 #291)',
#   '1 Soulbringer (Set4 #231)',
#   '1 Steward of the Past (Set1 #287)',
#   '4 Stonescar Magus (Set1 #288)',
#   '4 Subvert (Set1 #289)',
#   '4 Transmogrifier (Set4 #232)',
#   '4 Vainglory Patrol (Set3 #231)',
#   '4 Vile Varmint (Set4 #233)',
#   '4 Xenan Fanatic (Set2 #162)',
#   '1 Ashara, the Deadshot (Set1 #295)',
#   '4 Cover of Darkness (Set3 #232)',
#   '1 Grasping at Shadows (Set1 #292)',
#   '4 Grimy Alp-luachra (Set4 #235)',
#   "4 Headsman's Axe (Set3 #233)",
#   '4 Lethrai Bladewhirl (Set4 #236)',
#   '4 Lurking Sanguar (Set1 #293)',
#   '4 Merciless Stranger (Set1 #111)',
#   '4 Moonlit Gargoyle (Set3 #234)',
#   '1 Stonescar Scrapper (Set3 #236)',
#   '4 Stray into Shadow (Set1001 #9)',
#   '2 The End is Near (Set4 #237)',
#   '4 Triggerman (Set3 #237)',
#   '4 Umbren Coaxer (Set3 #238)',
#   '4 Umbren Reaper (Set1 #299)',
#   '4 Umbren Thirster (Set2 #165)',
#   '4 Cut Ties (Set4 #238)',
#   '4 Direwood Prowler (Set2 #166)',
#   '4 Direwood Rampager (Set1 #301)',
#   '2 Dizo, Cabal Chairman (Set3 #302)',
#   '4 Drifting Death (Set3 #239)',
#   '4 Finback Komonat (Set3 #240)',
#   '4 Gunrustler (Set3 #241)',
#   '4 Horsesnatcher Bat (Set1 #304)',
#   '4 Spirit Drain (Set1 #302)',
#   "1 Azindel's Gift (Set1 #306)",
#   '4 Cabal Rogue (Set2 #168)',
#   '1 Dangerous Bargain (Set3 #245)',
#   '4 Inspire Obedience (Set2 #169)',
#   '4 Repulsive Gorger (Set3 #246)',
#   '4 Shadowlands Feaster (Set1001 #10)',
#   '1 Vara, Fate-Touched (Set1 #307)',
#   '4 Praxis Banner (Set2 #171)',
#   '4 Seat of Impulse (Set0 #54)',
#   '4 Alluring Ember (Set2 #172)',
#   '4 Noble Firemane (Set2 #174)',
#   '4 Purify (Set2 #176)',
#   '4 Waker of Ancients (Set1002 #16)',
#   '4 Journeyman Armorer (Set2 #175)',
#   '4 Magus of Celerity (Set4 #241)',
#   '1 Mysterium Orb (Set3 #252)',
#   '4 Brilliant Discovery (Set2 #177)',
#   '4 Monolith Guardian (Set3 #253)',
#   '4 Recombobulate (Set4 #242)',
#   '4 Sandglass Juggernaut (Set1003 #16)',
#   '2 Shatterglass Mage (Set2 #181)',
#   "4 Talir's Choice (Set2 #180)",
#   '1 Workshop Forge (Set2 #182)',
#   '4 Sandglass Sentinel (Set2 #184)',
#   '2 Crest of Glory (Set4 #243)',
#   '4 Rakano Banner (Set1 #427)',
#   '4 Seat of Glory (Set0 #56)',
#   '2 Bulletshaper (Set4 #244)',
#   '4 Champion of Glory (Set1 #314)',
#   "4 Ijin's Choice (Set4 #245)",
#   '4 Crownwatch Deserter (Set1 #316)',
#   '4 Sower of Dissent (Set1003 #17)',
#   '4 Sword of Icaria (Set1 #315)',
#   '4 Whirling Duo (Set3 #254)',
#   '4 Battleblur Centaur (Set1 #319)',
#   '4 Longhorn Sergeant (Set1 #318)',
#   '4 Renegade Valkyrie (Set1 #321)',
#   '1 Righteous Fury (Set1 #322)',
#   '4 Field Captain (Set1 #324)',
#   '4 Jekk, the Bounty Hunter (Set1001 #11)',
#   '1 Icaria, the Liberator (Set1 #329)',
#   '4 Combrei Banner (Set1 #424)',
#   '2 Crest of Progress (Set4 #247)',
#   '4 Seat of Progress (Set0 #58)',
#   '2 Alessi, Combrei Archmage (Set4 #248)',
#   '4 Awakened Student (Set1 #331)',
#   '4 Desert Marshal (Set1 #332)',
#   '4 Jaril, Amaran Ghostblade (Set1003 #20)',
#   '4 Safe Return (Set1 #330)',
#   '4 Auric Record Keeper (Set3 #258)',
#   '4 Combrei Emissary (Set1001 #12)',
#   '4 Combrei Healer (Set1 #333)',
#   '1 Shush (Set3 #259)',
#   '2 Stand Together (Set1 #334)',
#   "1 Vodakhan's Staff (Set1 #336)",
#   '2 Copperhall Elite (Set1 #340)',
#   '4 Genetrix Irel IV (Set4 #307)',
#   '4 Karmic Guardian (Set1 #341)',
#   '2 Sword of Unity (Set4 #249)',
#   '1 The Great Parliament (Set1 #338)',
#   "2 Stronghold's Visage (Set1 #339)",
#   '1 Champion of Progress (Set1 #345)',
#   '4 Minotaur Ambassador (Set1 #346)',
#   "4 Siraf's Choice (Set4 #250)",
#   '4 Elysian Banner (Set1 #421)',
#   '4 Seat of Wisdom (Set0 #63)',
#   '1 Derry Cathain, Ripclaw Rider (Set4 #251)',
#   '4 Storm Lynx (Set1 #353)',
#   '4 Twinning Ritual (Set1 #79)',
#   '4 Amaran Camel (Set1 #357)',
#   '4 False Prince (Set1 #356)',
#   '4 Pteriax Hatchling (Set1 #354)',
#   '4 Avisaur Patriarch (Set1001 #13)',
#   '1 Champion of Wisdom (Set1 #358)',
#   "4 Cirso's Choice (Set4 #252)",
#   '4 Nesting Avisaur (Set1 #225)',
#   '4 Scaletender (Set3 #260)',
#   '2 Hunting Pteriax (Set1 #363)',
#   '2 Crest of Order (Set4 #253)',
#   '4 Hooru Banner (Set2 #216)',
#   '4 Seat of Order (Set0 #51)',
#   '4 Bring Down (Set2 #217)',
#   "4 Linebreaker's Shield (Set4 #254)",
#   '4 Vision of Austerity (Set1002 #17)',
#   '4 Aerialist Trainer (Set2 #219)',
#   "4 Eilyn's Choice (Set2 #220)",
#   '4 Hooru Pacifier (Set1003 #23)',
#   '4 Spellshield Architect (Set2 #221)',
#   '4 Long Live the Queen (Set4 #255)',
#   '2 Shelterwing Rider (Set2 #223)',
#   '4 Shield Bash (Set2 #224)',
#   '1 Champion of Order (Set2 #225)',
#   '4 Deepwood Ranger (Set3 #262)',
#   "4 Duelist's Blade (Set2 #226)",
#   '4 Highwind Glider (Set2 #227)',
#   '1 Meditative Stranger (Set2 #228)',
#   '4 Argenport Banner (Set2 #231)',
#   '4 Crest of Vengeance (Set3 #264)',
#   '4 Seat of Vengeance (Set0 #55)',
#   '4 Anointer of the Faithful (Set1003 #24)',
#   '4 Auric Bully (Set2 #232)',
#   "2 Inquisitor's Halberd (Set3 #273)",
#   '4 Rooftop Vigilante (Set3 #274)',
#   '4 Slay (Set2 #236)',
#   '4 Stonepowder Alchemist (Set2 #239)',
#   '1 Unfinished Business (Set4 #256)',
#   '4 Sanguine Sword (Set2 #238)',
#   '4 Streetwise Informant (Set2 #240)',
#   '4 Knight of Sorrow (Set4 #257)',
#   "4 Rolant's Choice (Set2 #243)",
#   '4 Tavrod, Auric Broker (Set1002 #18)',
#   '4 Valkyrie Denouncer (Set2 #244)',
#   '2 Crest of Fury (Set3 #266)',
#   '4 Seat of Fury (Set0 #53)',
#   '4 Skycrag Banner (Set2 #186)',
#   '4 Champion of Fury (Set2 #187)',
#   "4 Kaleb's Choice (Set2 #188)",
#   '4 Rockslide (Set2 #189)',
#   '4 Clan Hero (Set2 #190)',
#   '3 Crunch, the Hoarder (Set4 #258)',
#   '4 Pokpok, Rockpacker (Set1003 #18)',
#   "4 Hunter's Harpoon (Set2 #193)",
#   '4 Mortar (Set2 #194)',
#   '4 Storm Glider (Set2 #195)',
#   '4 Unexpected Results (Set1002 #19)',
#   '4 Bloodthirsty Brawler (Set4 #259)',
#   '4 Iceberg Warchief (Set3 #257)',
#   '2 Tamarys, the Geomancer (Set4 #308)',
#   '1 Towering Stranger (Set2 #196)',
#   '4 Topaz Drake (Set2 #198)',
#   '4 Crest of Cunning (Set3 #267)',
#   '4 Feln Banner (Set1 #417)',
#   '4 Seat of Cunning (Set0 #62)',
#   '4 Twilight Raptor (Set1 #379)',
#   '4 Gorgon Swiftblade (Set1 #377)',
#   '1 Grim Stranger (Set1 #372)',
#   '4 Haunting Scream (Set1 #374)',
#   "4 Rindra's Choice (Set4 #261)",
#   '1 Feln Bloodcaster (Set1 #386)',
#   '4 Gorgon Fanatic (Set1 #375)',
#   '4 Skywalk Enforcer (Set3 #276)',
#   "4 Trickster's Cloak (Set1 #369)",
#   '4 Ancient of the Ice Caves (Set4 #262)',
#   '4 Cabal Spymaster (Set1001 #14)',
#   '4 Feeding Time (Set1 #381)',
#   '4 Lethrai Skystrider (Set1003 #25)',
#   '1 Champion of Cunning (Set1 #371)',
#   '2 Spell Swipe (Set1 #373)',
#   '2 Withering Witch (Set1 #368)',
#   '2 Crest of Chaos (Set3 #268)',
#   '4 Seat of Chaos (Set0 #60)',
#   '4 Stonescar Banner (Set1 #419)',
#   '4 Combust (Set1 #392)',
#   '1 Hair-Trigger Stranger (Set1 #253)',
#   '4 Obsidian Golem (Set1 #398)',
#   '4 Treachery (Set1 #394)',
#   '4 Wyatt, Junk Collector (Set4 #306)',
#   '1 Champion of Chaos (Set1 #402)',
#   '4 Recycler (Set3 #269)',
#   '4 Stonescar Pickaxe (Set4 #263)',
#   "4 Jekk's Choice (Set4 #264)",
#   '4 Runic Revolver (Set1 #404)',
#   '4 Warband Chieftain (Set1 #395)',
#   '2 Failed Reflection (Set3 #270)',
#   '3 Infernal Tyrant (Set1 #390)',
#   "4 Smuggler's Stash (Set1 #396)",
#   '4 Crest of Mystery (Set4 #266)',
#   '4 Seat of Mystery (Set0 #61)',
#   '4 Xenan Banner (Set2 #201)',
#   '4 Bloodcall Invocation (Set2 #203)',
#   '4 Blistersting Wasp (Set2 #202)',
#   '4 Mitotic Wisp (Set1003 #22)',
#   "4 Vara's Choice (Set2 #206)",
#   '1 Ayan, the Abductor (Set2 #204)',
#   '4 Shadowlands Bonepicker (Set2 #205)',
#   '4 Duskwalker (Set3 #271)',
#   '4 Katra, the Devoted (Set2 #208)',
#   '4 Preserver of Dualities (Set4 #267)',
#   '4 Xenan Augury (Set2 #209)',
#   '4 Xenan Cupbearer (Set2 #210)',
#   '4 Bloodcall Invoker (Set2 #211)',
#   '1 Champion of Mystery (Set2 #213)',
#   '1 Prophetic Stranger (Set2 #214)',
#   "1 Cirso's Cleaver (Set4 #270)",
#   '4 Triumphant Stranger (Set1002 #21)',
#   '1 Nictotraxian (Set1001 #16)',
#   "4 Chairman's Contract (Set4 #271)",
#   '4 Common Cause (Set3 #279)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '4 Spiked Helm (Set1 #406)',
#   "4 Alchemist's Concoction (Set4 #272)",
#   '4 Family Charter (Set3 #280)',
#   '4 Horus Traver (Set1002 #23)',
#   '4 Seek Power (Set1 #408)',
#   '4 Veteran Strategist (Set4 #273)',
#   ...]}

# %% [markdown]
# ## _______________________________________________________

# %% [markdown]
# # II:  Import featured decks on home page, and export into list!

# %%
"""
First this cell compiles a list of links to each featured deck.
Sidenote: Don't need user info for this portion
This also opens a firefox browser because this is NOT done in headless mode. Investigate further later.
"""
browser = mechanicalsoup.Browser(soup_config={'features': 'lxml'})
deck_links = []
home_page = 'https://eternalwarcry.com'

# Response for home page
page = browser.get(home_page) # Contains a .soup object.

# Get each featured deck div on the homepage.
feature_divs = page.soup.findAll(class_= 'col-sm-6 col-md-4 col-sm-6 push-b')
for div in feature_divs:
    # Pulls link for each deck.
    deck_url = home_page + div.find('a')['href']
    # Appends to list of links.
    deck_links.append(deck_url)
    
print(deck_links) #Show list of links to each deck.
# Out:
# ['https://eternalwarcry.com/decks/details/Bu31Re651Tg/rank-1-haunted-posts', 'https://eternalwarcry.com/decks/details/-n52NWsp5Mc/chriseays-deck', 'https://eternalwarcry.com/decks/details/0hOctDjnFV0/zal-chi-do-you-love-me', 'https://eternalwarcry.com/decks/details/f4aivS7YKGw/feln-tempo-is-back-a-k-a-parry-is-a-good-card', 'https://eternalwarcry.com/decks/details/zQaZBwY7YuA/23-5-ecq-burning-hope-winchest-ramp', 'https://eternalwarcry.com/decks/details/tvInDyBOJPw/kiss-me-telut-2-0']

# %%
"""
 This cell goes to each link, clicks the export button, and puts each deck into a list with each card+count being a string.
 Note: We now need selenium to complete actions, because mechanicalsoup does not like javascript.
 Supernote: You may get a permission denied initially when running this, run it again; it will work.
"""
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys

# Call out location for firefox if your special like me and use quantum - This literally opens a browser everytime.
binary = FirefoxBinary(r'C:\Program Files\Firefox Developer Edition\firefox.exe')
driver = webdriver.Firefox(firefox_binary=binary) #Consider headless...
decks_messy = []

for link in deck_links:
    # Goto link for deck.
    driver.get(link)
    # Select "export-deck" button. (Using the Xpath; Mark recommends against this; Investigate later)
    button = driver.find_element_by_xpath('//*[@id="export-deck"]')
    # Click the export deck button
    button.click()
    # Now grab deck text from clipboard (literal head-firefox clipboard)
    deck_to_be_parsed = pyperclip.paste()
    decks_messy.append(deck_to_be_parsed)

decks_clean = [] # Make each card its own string in a list. Make market apart of this, spaced out by word
for deck in decks_messy:
    # Split single string of deck into list itself. (including market for easy access)
    current_deck = deck.split('\r\n')
    decks_clean.append(current_deck) # list containing lists of decks (lol)
decks_clean
# Out:
# [['4 Seat of Wisdom (Set0 #63)',
#   '2 Seat of Cunning (Set0 #62)',
#   '4 Seat of Mystery (Set0 #61)',
#   '3 Permafrost (Set1 #193)',
#   '4 Dark Return (Set1 #250)',
#   '3 Annihilate (Set1 #269)',
#   '4 Gorgon Fanatic (Set1 #375)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '3 Haunting Scream (Set1 #374)',
#   '3 Time Sigil (Set1 #63)',
#   '2 Primal Sigil (Set1 #187)',
#   '2 Shadow Sigil (Set1 #249)',
#   '2 Banish (Set2 #207)',
#   '2 Crest of Cunning (Set3 #267)',
#   '1 Crest of Wisdom (Set3 #261)',
#   '1 Crest of Mystery (Set4 #266)',
#   '3 Entangling Vines (Set4 #167)',
#   '4 Jennev Merchant (Set4 #169)',
#   '4 Teacher of Humility (Set4 #67)',
#   '4 Cykalis, the Burning Sand (Set5 #57)',
#   '4 Kerendon Steward (Set5 #159)',
#   "4 Torgov's Trading Post (Set5 #203)",
#   '4 Equivocate (Set1003 #21)',
#   '4 Shakedown (Set1004 #18)',
#   '--------------MARKET---------------',
#   '1 Permafrost (Set1 #193)',
#   '1 Mirror Image (Set1 #217)',
#   '1 Accelerated Evolution (Set1 #351)',
#   '1 Haunting Scream (Set1 #374)',
#   "1 Cirso's Cleaver (Set4 #270)"],
#  ['4 Seat of Glory (Set0 #56)',
#   '4 Oni Ronin (Set1 #13)',
#   '4 Warhelm (Set1 #14)',
#   '2 Ornate Katana (Set1 #23)',
#   '4 District Infantry (Set1 #134)',
#   '4 Torch (Set1 #8)',
#   '4 Finest Hour (Set1 #130)',
#   '4 Rakano Banner (Set1 #427)',
#   '4 Champion of Glory (Set1 #314)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '4 Fire Sigil (Set1 #1)',
#   '7 Justice Sigil (Set1 #126)',
#   '4 Whirling Duo (Set3 #254)',
#   '4 Master-at-Arms (Set4 #121)',
#   '2 Shugo Standard (Set4 #1)',
#   '4 Hojan, Crownbreaker (Set5 #86)',
#   '4 Avigraft (Set5 #95)',
#   '4 Highland Sharpshooter (Set5 #197)',
#   '4 Red Canyon Smuggler (Set5 #198)',
#   '--------------MARKET---------------',
#   '1 Obliterate (Set1 #48)',
#   "1 Elder's Feather (Set1 #128)",
#   '1 Vanquish (Set1 #143)',
#   '1 Deepforged Plate (Set1 #317)',
#   '1 Crownwatch Standard (Set4 #97)'],
#  ['4 Seat of Impulse (Set0 #54)',
#   '3 Seat of Wisdom (Set0 #63)',
#   '1 Seat of Fury (Set0 #53)',
#   '4 Sandstorm Titan (Set1 #99)',
#   '4 Seek Power (Set1 #408)',
#   '4 Torch (Set1 #8)',
#   '2 Permafrost (Set1 #193)',
#   '4 Wisdom of the Elders (Set1 #218)',
#   '2 Jotun Hurler (Set1 #227)',
#   '3 Fire Sigil (Set1 #1)',
#   '2 Time Sigil (Set1 #63)',
#   '3 Primal Sigil (Set1 #187)',
#   '4 Heart of the Vault (Set2 #183)',
#   '3 Strategize (Set3 #165)',
#   '4 Crest of Fury (Set3 #266)',
#   '1 Crest of Impulse (Set3 #251)',
#   '4 Crest of Wisdom (Set3 #261)',
#   '3 Jotun Feast-Caller (Set3 #187)',
#   '4 Jennev Merchant (Set4 #169)',
#   '3 Jennev Cargo (Set5 #242)',
#   '3 Display of Instinct (Set5 #244)',
#   '3 Zal Chi, Herald of War (Set5 #245)',
#   '3 Howling Peak (Set5 #219)',
#   '4 Equivocate (Set1003 #21)',
#   '--------------MARKET---------------',
#   '1 Permafrost (Set1 #193)',
#   '1 Jennev Cargo (Set5 #242)',
#   '1 Zal Chi, Herald of War (Set5 #245)',
#   '1 Howling Peak (Set5 #219)',
#   '1 Hailstorm (Set1003 #11)'],
#  ["2 Vara's Favor (Set0 #35)",
#   '4 Seat of Cunning (Set0 #62)',
#   '4 Permafrost (Set1 #193)',
#   '4 Argenport Instigator (Set1 #268)',
#   '4 Feln Banner (Set1 #417)',
#   '4 Twilight Raptor (Set1 #379)',
#   '2 Midnight Gale (Set1 #378)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '4 Cabal Countess (Set1 #506)',
#   '3 Rapid Shot (Set1 #259)',
#   '4 Primal Sigil (Set1 #187)',
#   '6 Shadow Sigil (Set1 #249)',
#   '3 Unseal (Set3 #167)',
#   '3 Cabal Standard (Set4 #193)',
#   '4 Dusk Raider (Set4 #153)',
#   '2 Fenris Nightshade (Set4 #204)',
#   '4 Kerendon Merchant (Set4 #217)',
#   '2 Frostwave (Set5 #114)',
#   '4 Parry (Set5 #123)',
#   '4 Ripknife Assassin (Set1003 #13)',
#   '4 Shakedown (Set1004 #18)',
#   '--------------MARKET---------------',
#   '1 Suffocate (Set1 #251)',
#   '1 Madness (Set1 #267)',
#   '1 Lethrai Falchion (Set1 #285)',
#   "1 Rindra's Choice (Set4 #261)",
#   '1 Vara, Vengeance-Seeker (Set1004 #19)'],
#  ['4 Seat of Chaos (Set0 #60)',
#   '4 Torch (Set1 #8)',
#   '1 Auric Runehammer (Set1 #166)',
#   '4 Privilege of Rank (Set1 #157)',
#   '1 Fire Sigil (Set1 #1)',
#   '7 Justice Sigil (Set1 #126)',
#   '1 Shadow Sigil (Set1 #249)',
#   '3 Slay (Set2 #236)',
#   '4 Crest of Chaos (Set3 #268)',
#   '4 Crest of Vengeance (Set3 #264)',
#   '4 Bulletshaper (Set4 #244)',
#   '4 Crest of Glory (Set4 #243)',
#   '4 Rizahn, Greatbow Master (Set4 #246)',
#   '4 Xo of the Endless Hoard (Set5 #36)',
#   '4 Red Canyon Smuggler (Set5 #198)',
#   '4 Lost Scroll (Set5 #208)',
#   '4 Hidden Road Smuggler (Set5 #210)',
#   '4 Winchest Cargo (Set5 #237)',
#   '4 Display of Ambition (Set5 #239)',
#   '4 Quarry (Set1001 #15)',
#   '2 Vara, Vengeance-Seeker (Set1004 #19)',
#   '--------------MARKET---------------',
#   '1 Vanquish (Set1 #143)',
#   '1 Statuary Maiden (Set1 #387)',
#   "1 Martyr's Chains (Set5 #110)",
#   "1 Regent's Tomb (Set5 #213)",
#   '1 Bore (Set1003 #1)'],
#  ["3 Vara's Favor (Set0 #35)",
#   '4 Seat of Vengeance (Set0 #55)',
#   '3 Valkyrie Enforcer (Set1 #151)',
#   '2 Auric Runehammer (Set1 #166)',
#   '3 Sabotage (Set1 #252)',
#   '7 Justice Sigil (Set1 #126)',
#   '6 Shadow Sigil (Set1 #249)',
#   '4 Argenport Banner (Set2 #231)',
#   '4 Slay (Set2 #236)',
#   '4 Crest of Vengeance (Set3 #264)',
#   "2 Vanquisher's Blade (Set4 #112)",
#   '4 Defiance (Set5 #77)',
#   '4 Hojan, Crownbreaker (Set5 #86)',
#   '3 Avigraft (Set5 #95)',
#   "4 Rhysta, Acantha's Herald (Set5 #168)",
#   '4 Lost Scroll (Set5 #208)',
#   '4 Hidden Road Smuggler (Set5 #210)',
#   "4 Telut, Queen's Hand (Set1004 #12)",
#   '2 Unwavering Exorcist (Set1004 #9)',
#   '4 Vara, Vengeance-Seeker (Set1004 #19)',
#   '--------------MARKET---------------',
#   '1 Vanquish (Set1 #143)',
#   '1 Devastating Setback (Set3 #226)',
#   '1 Amilli, Cloudmarshal (Set3 #136)',
#   "1 Martyr's Chains (Set5 #110)",
#   "1 Regent's Tomb (Set5 #213)"]]

# %%
decks_clean[0] # Yay! A Deck!
# Out:
# ['4 Seat of Wisdom (Set0 #63)',
#  '2 Seat of Cunning (Set0 #62)',
#  '4 Seat of Mystery (Set0 #61)',
#  '3 Permafrost (Set1 #193)',
#  '4 Dark Return (Set1 #250)',
#  '3 Annihilate (Set1 #269)',
#  '4 Gorgon Fanatic (Set1 #375)',
#  '4 Diplomatic Seal (Set1 #425)',
#  '3 Haunting Scream (Set1 #374)',
#  '3 Time Sigil (Set1 #63)',
#  '2 Primal Sigil (Set1 #187)',
#  '2 Shadow Sigil (Set1 #249)',
#  '2 Banish (Set2 #207)',
#  '2 Crest of Cunning (Set3 #267)',
#  '1 Crest of Wisdom (Set3 #261)',
#  '1 Crest of Mystery (Set4 #266)',
#  '3 Entangling Vines (Set4 #167)',
#  '4 Jennev Merchant (Set4 #169)',
#  '4 Teacher of Humility (Set4 #67)',
#  '4 Cykalis, the Burning Sand (Set5 #57)',
#  '4 Kerendon Steward (Set5 #159)',
#  "4 Torgov's Trading Post (Set5 #203)",
#  '4 Equivocate (Set1003 #21)',
#  '4 Shakedown (Set1004 #18)',
#  '--------------MARKET---------------',
#  '1 Permafrost (Set1 #193)',
#  '1 Mirror Image (Set1 #217)',
#  '1 Accelerated Evolution (Set1 #351)',
#  '1 Haunting Scream (Set1 #374)',
#  "1 Cirso's Cleaver (Set4 #270)"]

# %% [markdown]
# # III: Compare cards and count to reach a similarity percentage!

# %%
# Verify we have our featured decks for the week.
decks_clean
# Out:
# [['4 Seat of Wisdom (Set0 #63)',
#   '2 Seat of Cunning (Set0 #62)',
#   '4 Seat of Mystery (Set0 #61)',
#   '3 Permafrost (Set1 #193)',
#   '4 Dark Return (Set1 #250)',
#   '3 Annihilate (Set1 #269)',
#   '4 Gorgon Fanatic (Set1 #375)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '3 Haunting Scream (Set1 #374)',
#   '3 Time Sigil (Set1 #63)',
#   '2 Primal Sigil (Set1 #187)',
#   '2 Shadow Sigil (Set1 #249)',
#   '2 Banish (Set2 #207)',
#   '2 Crest of Cunning (Set3 #267)',
#   '1 Crest of Wisdom (Set3 #261)',
#   '1 Crest of Mystery (Set4 #266)',
#   '3 Entangling Vines (Set4 #167)',
#   '4 Jennev Merchant (Set4 #169)',
#   '4 Teacher of Humility (Set4 #67)',
#   '4 Cykalis, the Burning Sand (Set5 #57)',
#   '4 Kerendon Steward (Set5 #159)',
#   "4 Torgov's Trading Post (Set5 #203)",
#   '4 Equivocate (Set1003 #21)',
#   '4 Shakedown (Set1004 #18)',
#   '--------------MARKET---------------',
#   '1 Permafrost (Set1 #193)',
#   '1 Mirror Image (Set1 #217)',
#   '1 Accelerated Evolution (Set1 #351)',
#   '1 Haunting Scream (Set1 #374)',
#   "1 Cirso's Cleaver (Set4 #270)"],
#  ['4 Seat of Glory (Set0 #56)',
#   '4 Oni Ronin (Set1 #13)',
#   '4 Warhelm (Set1 #14)',
#   '2 Ornate Katana (Set1 #23)',
#   '4 District Infantry (Set1 #134)',
#   '4 Torch (Set1 #8)',
#   '4 Finest Hour (Set1 #130)',
#   '4 Rakano Banner (Set1 #427)',
#   '4 Champion of Glory (Set1 #314)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '4 Fire Sigil (Set1 #1)',
#   '7 Justice Sigil (Set1 #126)',
#   '4 Whirling Duo (Set3 #254)',
#   '4 Master-at-Arms (Set4 #121)',
#   '2 Shugo Standard (Set4 #1)',
#   '4 Hojan, Crownbreaker (Set5 #86)',
#   '4 Avigraft (Set5 #95)',
#   '4 Highland Sharpshooter (Set5 #197)',
#   '4 Red Canyon Smuggler (Set5 #198)',
#   '--------------MARKET---------------',
#   '1 Obliterate (Set1 #48)',
#   "1 Elder's Feather (Set1 #128)",
#   '1 Vanquish (Set1 #143)',
#   '1 Deepforged Plate (Set1 #317)',
#   '1 Crownwatch Standard (Set4 #97)'],
#  ['4 Seat of Impulse (Set0 #54)',
#   '3 Seat of Wisdom (Set0 #63)',
#   '1 Seat of Fury (Set0 #53)',
#   '4 Sandstorm Titan (Set1 #99)',
#   '4 Seek Power (Set1 #408)',
#   '4 Torch (Set1 #8)',
#   '2 Permafrost (Set1 #193)',
#   '4 Wisdom of the Elders (Set1 #218)',
#   '2 Jotun Hurler (Set1 #227)',
#   '3 Fire Sigil (Set1 #1)',
#   '2 Time Sigil (Set1 #63)',
#   '3 Primal Sigil (Set1 #187)',
#   '4 Heart of the Vault (Set2 #183)',
#   '3 Strategize (Set3 #165)',
#   '4 Crest of Fury (Set3 #266)',
#   '1 Crest of Impulse (Set3 #251)',
#   '4 Crest of Wisdom (Set3 #261)',
#   '3 Jotun Feast-Caller (Set3 #187)',
#   '4 Jennev Merchant (Set4 #169)',
#   '3 Jennev Cargo (Set5 #242)',
#   '3 Display of Instinct (Set5 #244)',
#   '3 Zal Chi, Herald of War (Set5 #245)',
#   '3 Howling Peak (Set5 #219)',
#   '4 Equivocate (Set1003 #21)',
#   '--------------MARKET---------------',
#   '1 Permafrost (Set1 #193)',
#   '1 Jennev Cargo (Set5 #242)',
#   '1 Zal Chi, Herald of War (Set5 #245)',
#   '1 Howling Peak (Set5 #219)',
#   '1 Hailstorm (Set1003 #11)'],
#  ["2 Vara's Favor (Set0 #35)",
#   '4 Seat of Cunning (Set0 #62)',
#   '4 Permafrost (Set1 #193)',
#   '4 Argenport Instigator (Set1 #268)',
#   '4 Feln Banner (Set1 #417)',
#   '4 Twilight Raptor (Set1 #379)',
#   '2 Midnight Gale (Set1 #378)',
#   '4 Diplomatic Seal (Set1 #425)',
#   '4 Cabal Countess (Set1 #506)',
#   '3 Rapid Shot (Set1 #259)',
#   '4 Primal Sigil (Set1 #187)',
#   '6 Shadow Sigil (Set1 #249)',
#   '3 Unseal (Set3 #167)',
#   '3 Cabal Standard (Set4 #193)',
#   '4 Dusk Raider (Set4 #153)',
#   '2 Fenris Nightshade (Set4 #204)',
#   '4 Kerendon Merchant (Set4 #217)',
#   '2 Frostwave (Set5 #114)',
#   '4 Parry (Set5 #123)',
#   '4 Ripknife Assassin (Set1003 #13)',
#   '4 Shakedown (Set1004 #18)',
#   '--------------MARKET---------------',
#   '1 Suffocate (Set1 #251)',
#   '1 Madness (Set1 #267)',
#   '1 Lethrai Falchion (Set1 #285)',
#   "1 Rindra's Choice (Set4 #261)",
#   '1 Vara, Vengeance-Seeker (Set1004 #19)'],
#  ['4 Seat of Chaos (Set0 #60)',
#   '4 Torch (Set1 #8)',
#   '1 Auric Runehammer (Set1 #166)',
#   '4 Privilege of Rank (Set1 #157)',
#   '1 Fire Sigil (Set1 #1)',
#   '7 Justice Sigil (Set1 #126)',
#   '1 Shadow Sigil (Set1 #249)',
#   '3 Slay (Set2 #236)',
#   '4 Crest of Chaos (Set3 #268)',
#   '4 Crest of Vengeance (Set3 #264)',
#   '4 Bulletshaper (Set4 #244)',
#   '4 Crest of Glory (Set4 #243)',
#   '4 Rizahn, Greatbow Master (Set4 #246)',
#   '4 Xo of the Endless Hoard (Set5 #36)',
#   '4 Red Canyon Smuggler (Set5 #198)',
#   '4 Lost Scroll (Set5 #208)',
#   '4 Hidden Road Smuggler (Set5 #210)',
#   '4 Winchest Cargo (Set5 #237)',
#   '4 Display of Ambition (Set5 #239)',
#   '4 Quarry (Set1001 #15)',
#   '2 Vara, Vengeance-Seeker (Set1004 #19)',
#   '--------------MARKET---------------',
#   '1 Vanquish (Set1 #143)',
#   '1 Statuary Maiden (Set1 #387)',
#   "1 Martyr's Chains (Set5 #110)",
#   "1 Regent's Tomb (Set5 #213)",
#   '1 Bore (Set1003 #1)'],
#  ["3 Vara's Favor (Set0 #35)",
#   '4 Seat of Vengeance (Set0 #55)',
#   '3 Valkyrie Enforcer (Set1 #151)',
#   '2 Auric Runehammer (Set1 #166)',
#   '3 Sabotage (Set1 #252)',
#   '7 Justice Sigil (Set1 #126)',
#   '6 Shadow Sigil (Set1 #249)',
#   '4 Argenport Banner (Set2 #231)',
#   '4 Slay (Set2 #236)',
#   '4 Crest of Vengeance (Set3 #264)',
#   "2 Vanquisher's Blade (Set4 #112)",
#   '4 Defiance (Set5 #77)',
#   '4 Hojan, Crownbreaker (Set5 #86)',
#   '3 Avigraft (Set5 #95)',
#   "4 Rhysta, Acantha's Herald (Set5 #168)",
#   '4 Lost Scroll (Set5 #208)',
#   '4 Hidden Road Smuggler (Set5 #210)',
#   "4 Telut, Queen's Hand (Set1004 #12)",
#   '2 Unwavering Exorcist (Set1004 #9)',
#   '4 Vara, Vengeance-Seeker (Set1004 #19)',
#   '--------------MARKET---------------',
#   '1 Vanquish (Set1 #143)',
#   '1 Devastating Setback (Set3 #226)',
#   '1 Amilli, Cloudmarshal (Set3 #136)',
#   "1 Martyr's Chains (Set5 #110)",
#   "1 Regent's Tomb (Set5 #213)"]]

# %%
collection['my_collection'] # Verify we have our collection imported
# Out:
# ['4 Granite Monument (Set1 #423)',
#  '4 Granite Waystone (Set3 #1)',
#  '4 Shugo Standard (Set4 #1)',
#  '4 Helpful Doorbot (Set3 #2)',
#  '2 Trail Stories (Set1 #188)',
#  '4 Drifter (Set4 #2)',
#  '4 Feed the Flames (Set4 #3)',
#  '4 Firemane Cub (Set2 #1)',
#  '4 Forge Wolf (Set2 #2)',
#  '4 Grenadin Drone (Set1 #5)',
#  '4 Heavy Axe (Set1 #4)',
#  '4 Hidden Shiv (Set2 #4)',
#  '4 Iceberg Frontrunner (Set3 #3)',
#  "4 Kaleb's Intervention (Set3 #4)",
#  "4 Light 'em Up (Set4 #4)",
#  '4 Longbarrel (Set4 #5)',
#  '4 Mindfire (Set4 #6)',
#  '4 On the Hunt (Set2 #5)',
#  '4 Oni Dragonsmith (Set1003 #2)',
#  '4 Oni Ronin (Set1 #13)',
#  '4 Pummel (Set2 #6)',
#  '4 Pyroknight (Set1 #16)',
#  '4 Rambot (Set4 #7)',
#  '4 Ruin (Set1 #15)',
#  '4 Ruthless Stranger (Set1 #11)',
#  '4 Scrap Hound (Set3 #6)',
#  '4 Temper (Set1 #10)',
#  '4 Ticking Grenadin (Set1 #12)',
#  '4 Torch (Set1 #8)',
#  '4 Warhelm (Set1 #14)',
#  '4 Young Gun (Set2 #3)',
#  '4 Ankle Cutter (Set4 #8)',
#  '4 Bladekin Apprentice (Set1 #22)',
#  '4 Blazing Renegade (Set0 #4)',
#  '4 Blinkwolf (Set2 #7)',
#  '4 Consuming Flames (Set4 #9)',
#  '4 Disassembler (Set3 #8)',
#  '4 Flame Blast (Set1 #2)',
#  '3 Flamebelcher (Set4 #10)',
#  '4 Flamefang Charmer (Set4 #18)',
#  '4 Grenarender (Set4 #11)',
#  '4 Hotblood Barbarian (Set4 #12)',
#  '4 Into the Furnace (Set3 #9)',
#  "4 Kaleb's Favor (Set0 #3)",
#  '4 Oni Cavediver (Set3 #11)',
#  '4 Ornate Katana (Set1 #23)',
#  '4 Piercing Shot (Set1 #25)',
#  '4 Pyre Adept (Set1 #21)',
#  '1 Quicktrigger Outlaw (Set4 #13)',
#  '4 Rakano Outlaw (Set1 #20)',
#  '4 Rampage (Set1 #17)',
#  '4 Ruination Sledge (Set4 #14)',
#  "4 Smith's Hammer (Set2 #8)",
#  '4 Spark Hatcher (Set3 #12)',
#  '4 Trick Shot (Set4 #16)',
#  '4 Unpredictable Outlaw (Set3 #13)',
#  '1 Yeti Sage (Set3 #14)',
#  '4 Assembly Line (Set1 #29)',
#  "4 Backpacker's Machete (Set3 #15)",
#  '4 Censari Brigand (Set1 #34)',
#  '1 Factory Quota (Set4 #17)',
#  '4 Fevered Scout (Set1 #512)',
#  '4 First-Shot Rioter (Set3 #17)',
#  '4 Frontier Bard (Set4 #19)',
#  '4 Granite Acolyte (Set1 #31)',
#  '4 Granite Ring (Set2 #9)',
#  '4 Grenade (Set2 #10)',
#  '4 Hipshot (Set2 #11)',
#  '4 Hoof Slash (Set3 #18)',
#  '4 Ixtun Merchant (Set4 #21)',
#  '4 Jawbone Hatchet (Set2 #12)',
#  '4 Manufacture (Set4 #22)',
#  '4 Oni Eulogist (Set4 #23)',
#  '4 Oni Quartermaster (Set1 #32)',
#  '4 Rakano Flagbearer (Set1 #27)',
#  '4 Rally (Set1 #33)',
#  '4 Rebel Sharpshooter (Set1 #30)',
#  '4 Refracted Sentinel (Set4 #24)',
#  '4 Ruincrawler Yeti (Set3 #22)',
#  '4 Rusty Grenamotive (Set4 #26)',
#  "4 Shogun's Scepter (Set1 #26)",
#  '4 Skycrag Huntsman (Set3 #24)',
#  '4 Sparkbot (Set2 #13)',
#  '4 Stoneshaker (Set2 #15)',
#  '4 Temple Raider (Set3 #25)',
#  '4 Tumblebang (Set3 #27)',
#  '4 Twinbarrel (Set2 #16)',
#  '4 Warpainter (Set4 #27)',
#  "4 Won't Be Pretty (Set4 #28)",
#  '4 Ancient Defenses (Set3 #28)',
#  '4 Audacious Bandit (Set2 #17)',
#  '4 Barbarian Camp (Set3 #29)',
#  '4 Burn Out (Set1 #28)',
#  '4 Centaur Outrider (Set1 #35)',
#  '4 Clan Wallbreaker (Set4 #29)',
#  '4 Cloud of Ash (Set1 #39)',
#  '4 Crimson Firemaw (Set1002 #3)',
#  '4 Furnace Mage (Set1 #40)',
#  '4 Gravemarker Oni (Set4 #39)',
#  '4 Grenadin Cannoneer (Set2 #20)',
#  '4 Guerrilla Fighter (Set1 #36)',
#  '4 Hellfire Oni (Set3 #30)',
#  '4 Iceberg Scattershot (Set4 #32)',
#  '4 Magma Javelin (Set1 #41)',
#  '4 Morningstar (Set1 #510)',
#  '4 Outlands Brute (Set2 #18)',
#  '4 Outlands Sniper (Set1 #42)',
#  '4 Overheat (Set4 #34)',
#  '4 Rebel Illuminator (Set1 #43)',
#  '4 Recogulator (Set1 #37)',
#  '4 Reforge (Set2 #23)',
#  '4 Scalechannel Sorcerer (Set4 #35)',
#  '2 Steelfang Chakram (Set1 #38)',
#  '4 Stonescar Sawed-Off (Set3 #32)',
#  '4 Swift Stranger (Set2 #24)',
#  '4 Thunderhoof Warrior (Set2 #25)',
#  '4 Wandering Forge (Set3 #33)',
#  '4 Welding Torch (Set4 #36)',
#  '3 Yushkov, the Usurper (Set4 #310)',
#  '4 Bait (Set1001 #2)',
#  '4 Calderan Gunsmith (Set1 #46)',
#  '4 Centaur Raidleader (Set1 #50)',
#  '4 Dustblind (Set2 #19)',
#  '4 Dusthoof Brawler (Set1 #49)',
#  '4 Fiery Fissure (Set4 #38)',
#  '4 Flash Fire (Set0 #6)',
#  '4 Gun Down (Set2 #26)',
#  '2 Infernus (Set1 #45)',
#  '4 Oni Striker (Set1 #44)',
#  '4 Pit Fighter (Set2 #27)',
#  '4 Powderkeg Rider (Set3 #38)',
#  '4 Robobuddy (Set4 #40)',
#  '4 Staff of the Arch-Magister (Set3 #39)',
#  '4 Stonepowder Heretic (Set2 #29)',
#  '4 Wildfire Censari (Set4 #41)',
#  "4 Barkeep's Friend (Set3 #40)",
#  '4 Cannonbearer (Set2 #31)',
#  '4 Crowd Favorite (Set1 #58)',
#  '1 Dashing Rapscallion (Set4 #43)',
#  '1 End of the Barrel (Set4 #44)',
#  '4 Frontline Cyclops (Set1 #53)',
#  '4 Hellfire Rifle (Set1 #55)',
#  '4 Oni Gunwright (Set3 #42)',
#  '4 Pyre Elemental (Set4 #45)',
#  '4 Stonescar Maul (Set1 #52)',
#  '4 Tempered Sentinel (Set3 #45)',
#  '4 Burning Glaive (Set2 #33)',
#  '4 Core Scavenger (Set4 #46)',
#  '4 Final Shot (Set4 #47)',
#  '4 Improvised Rubbler (Set3 #47)',
#  '2 Steelbound Dragon (Set1 #60)',
#  '4 Heroic Bravo (Set3 #50)',
#  '1 Kaleb, Uncrowned Prince (Set1 #61)',
#  '4 Sindok, Rage Incarnate (Set2 #34)',
#  '4 Amber Monument (Set1 #420)',
#  '4 Amber Waystone (Set3 #51)',
#  '4 Temple Standard (Set4 #49)',
#  '4 Sand Warrior (Set1 #64)',
#  '4 Amaran Shoveler (Set3 #53)',
#  '4 Ancient Bauble (Set3 #54)',
#  '4 Cult Aspirant (Set2 #35)',
#  '4 Entrancer (Set4 #51)',
#  '4 Envelop (Set2 #36)',
#  '4 Excavate (Set1 #71)',
#  '4 Excavation Assistant (Set2 #37)',
#  '4 Gloaming Wisp (Set3 #55)',
#  '1 Hesitate (Set3 #56)',
#  '4 Humbug (Set1 #72)',
#  '4 Infinite Hourglass (Set1 #67)',
#  '4 Initiate of the Sands (Set1 #74)',
#  '4 Jibbering Jackal (Set4 #52)',
#  '4 Journey Guide (Set4 #53)',
#  '4 Lucky Prospector (Set3 #57)',
#  '4 Meditation (Set4 #54)',
#  '4 Ornamental Daggers (Set1 #69)',
#  '1 Pathlighter (Set4 #55)',
#  "4 Predator's Instinct (Set1 #75)",
#  '1 Randori (Set4 #56)',
#  '4 Sanctuary Priest (Set1 #73)',
#  '3 Sandstorm Scarf (Set4 #50)',
#  '4 Silence (Set0 #9)',
#  '4 Slow (Set1 #70)',
#  '4 Staff of Speed (Set4 #57)',
#  "4 Talir's Intervention (Set3 #58)",
#  '4 Training Ground (Set4 #59)',
#  '4 Water of Life (Set1 #68)',
#  '4 Accelerate (Set1 #85)',
#  '1 Accelerated Impact (Set3 #60)',
#  '3 Amaran Armadillo (Set4 #60)',
#  '4 Bold Adventurer (Set1 #77)',
#  '1 Copper Conduit (Set1 #66)',
#  '4 Cryptic Etchings (Set3 #62)',
#  '4 Disjunction (Set3 #63)',
#  '1 Ephemeral Wisp (Set1 #84)',
#  '1 Evelina, Valley Searcher (Set2 #48)',
#  '4 Find the Way (Set1 #513)',
#  '4 Friendly Wisp (Set1 #82)',
#  '4 Illumination Wisp (Set4 #61)',
#  '4 Last Rites (Set4 #62)',
#  '4 Learned Herbalist (Set4 #63)',
#  '4 Living Example (Set4 #64)',
#  '4 Living Offering (Set4 #65)',
#  '4 Nocturnal Creeper (Set3 #64)',
#  '4 Oasis Seeker (Set2 #41)',
#  '4 Refresh (Set1 #501)',
#  '4 Sand Viper (Set2 #42)',
#  '4 Sandglass Parma (Set4 #66)',
#  '4 Sandstorm (Set2 #43)',
#  '4 Sauropod Wrangler (Set1 #83)',
#  '4 Synchronized Strike (Set1 #88)',
#  "4 Talir's Favored (Set0 #11)",
#  '4 Teleport (Set1 #80)',
#  '4 Temple Scribe (Set1 #502)',
#  '4 Trail Maker (Set3 #65)',
#  '4 Trail Runner (Set2 #39)',
#  '4 Xenan Initiation (Set2 #44)',
#  '4 Ageless Mentor (Set1 #90)',
#  '4 Amaran Stinger (Set4 #68)',
#  '4 Amber Acolyte (Set1 #93)',
#  '4 Amber Ring (Set2 #45)',
#  '3 Arcanum Hourglass (Set4 #69)',
#  '4 Auralian Merchant (Set4 #70)',
#  '4 Avirax Familiar (Set2 #46)',
#  '4 Baying Serasaur (Set3 #66)',
#  '3 Clockroach (Set1 #94)',
#  '4 Decay (Set1 #95)',
#  '4 Deft Strike (Set4 #71)',
#  '4 Determined Stranger (Set1 #92)',
#  '1 Dig Site (Set3 #67)',
#  '4 Disciplined Amanera (Set2 #47)',
#  '4 Dispel (Set1 #91)',
#  '4 Dune Phantom (Set1 #89)',
#  '4 Gravetender (Set4 #72)',
#  '4 Initiation Bell (Set4 #73)',
#  '4 Lastlight Infusion (Set3 #68)',
#  '2 Lunar Magus (Set3 #69)',
#  '4 Moondial (Set3 #70)',
#  '4 Oasis Sanctuary (Set0 #15)',
#  '4 Premonition Wisp (Set3 #71)',
#  '4 Scorpion Wasp (Set1 #96)',
#  '4 Seasoned Spelunker (Set3 #72)',
#  '4 Secret Pages (Set1 #81)',
#  '4 Serene Excavator (Set3 #73)',
#  '4 Sirocco Elementalist (Set4 #74)',
#  '4 Spiteful Lumen (Set4 #84)',
#  '4 Unlock Potential (Set1 #76)',
#  '4 Watchful Amanera (Set4 #75)',
#  '1 Wurmcalling (Set4 #76)',
#  '4 Ageless Sentinel (Set3 #74)',
#  '4 Ancient Lore (Set1 #105)',
#  '4 Archive Curator (Set2 #50)',
#  '4 Bolster (Set2 #51)',
#  '4 Camp Physician (Set2 #52)',
#  '4 Devoted Theurge (Set1002 #6)',
#  '4 Fierce Mosaraptor (Set4 #77)',
#  '4 Gathering Lights (Set4 #78)',
#  "4 Healer's Cloak (Set1 #98)",
#  '4 Hissing Spiketail (Set3 #77)',
#  '4 Horned Vorlunk (Set1 #503)',
#  '1 Insatiable Serasaur (Set4 #80)',
#  '4 Insistent Automaton (Set3 #78)',
#  '4 Lost in the Mist (Set3 #79)',
#  '4 Lumen Attendant (Set4 #81)',
#  "1 Marisen's Disciple (Set1 #104)",
#  '4 Memento Mori (Set1003 #4)',
#  '4 Primeval Plover (Set4 #82)',
#  '4 Sandspout Mirage (Set4 #83)',
#  '1 Sandstorm Titan (Set1 #99)',
#  '4 Snapping Brushstalker (Set2 #53)',
#  '4 Stinging Wind (Set4 #85)',
#  '4 Striped Araktodon (Set2 #54)',
#  '4 Timekeeper (Set0 #14)',
#  '4 Towertop Patrol (Set1 #101)',
#  '4 Venom Rider (Set1003 #5)',
#  "4 Viper's Bite (Set2 #55)",
#  '4 Wurmstone (Set4 #86)',
#  '4 Xenan Guardian (Set1 #102)',
#  '1 Xenan Obelisk (Set1 #103)',
#  '4 Amaran Archaeologist (Set2 #56)',
#  '4 Awakened Sentinel (Set2 #57)',
#  '4 Battle-Tested Stranger (Set2 #58)',
#  '4 First Watch (Set3 #82)',
#  '4 Fishing Dinoch (Set3 #83)',
#  '4 Frenzied Omnivore (Set3 #84)',
#  '4 Lumen Defender (Set1 #115)',
#  '4 Mistress of Light (Set4 #92)',
#  '4 Pensive Lumen (Set4 #88)',
#  '4 Praxis Displacer (Set1 #100)',
#  '4 Sandbinder Sentinel (Set3 #85)',
#  '4 Time Weaver (Set2 #62)',
#  '4 Towering Terrazon (Set1 #114)',
#  '4 Twinbrood Sauropod (Set1 #113)',
#  '4 Vital Arcana (Set4 #89)',
#  '4 Wurmic Chanter (Set4 #90)',
#  '1 Divining Rod (Set1 #109)',
#  '4 Humbug Swarm (Set2 #60)',
#  '4 Lumen Shepherd (Set1 #117)',
#  '1 Mystic Ascendant (Set1 #116)',
#  '4 Pack Hunt (Set2 #61)',
#  '4 Panoptic Guardian (Set3 #89)',
#  '4 Passage of Eons (Set1001 #3)',
#  '4 Plated Goliath (Set2 #64)',
#  '4 Timeworn Sentinel (Set3 #90)',
#  '1 Tomb Protector (Set3 #91)',
#  '4 Voyaging Lumen (Set2 #66)',
#  '4 Dormant Sentinel (Set1 #120)',
#  '4 Elysian Pathfinder (Set1 #108)',
#  '1 Hall of Lost Kings (Set1 #121)',
#  '4 Hibernating Behemoth (Set1001 #4)',
#  '4 Pillar of Amar (Set1 #122)',
#  '1 Predatory Carnosaur (Set1 #118)',
#  '4 Reality Shift (Set4 #94)',
#  '4 Subterranean Sentry (Set4 #95)',
#  '4 Belching Behemoth (Set2 #68)',
#  '4 Intriguing Ancient (Set3 #95)',
#  '1 Talir, Who Sees Beyond (Set1 #124)',
#  '4 Scourstone Sentinel (Set3 #98)',
#  '4 Foraging Sauropod (Set3 #99)',
#  '4 Crownwatch Standard (Set4 #97)',
#  '4 Emerald Monument (Set1 #422)',
#  '4 Emerald Waystone (Set3 #101)',
#  '4 Harmless Question (Set4 #98)',
#  '4 Crownwatch Squire (Set2 #69)',
#  '4 Detain (Set1 #133)',
#  '4 District Infantry (Set1 #134)',
#  "4 Elder's Feather (Set1 #128)",
#  '4 Finest Hour (Set1 #130)',
#  '4 Humble Instructor (Set3 #103)',
#  '4 Ironfist Faithful (Set4 #99)',
#  '4 Lingering Influence (Set4 #100)',
#  '4 Minotaur Oathkeeper (Set2 #70)',
#  "4 Peacekeeper's Helm (Set4 #101)",
#  "4 Rolant's Intervention (Set3 #104)",
#  '4 Sharpened Reflex (Set4 #102)',
#  '4 Spire Spellsword (Set4 #103)',
#  '4 Steadfast Deputy (Set1 #504)',
#  '4 Steady Marshal (Set3 #105)',
#  '4 Tinker Apprentice (Set1 #131)',
#  '4 Valkyrie Aspirant (Set1 #127)',
#  '1 Whetstone (Set3 #107)',
#  '4 Arcane Defense (Set4 #104)',
#  '4 Argenport Soldier (Set1 #135)',
#  '1 Bar the Gates (Set4 #105)',
#  '4 Barricade (Set4 #106)',
#  '4 Copperhall Herald (Set2 #71)',
#  '4 Copperhall Porter (Set3 #108)',
#  '4 Crackshot Fugitive (Set3 #109)',
#  '4 Crownwatch Longsword (Set1 #142)',
#  '4 Crownwatch Paladin (Set1 #139)',
#  '4 Encouragement (Set4 #107)',
#  '4 Icaria, Valkyrie Captain (Set1003 #7)',
#  '4 Inspire (Set1 #129)',
#  '4 Master-at-Arms (Set4 #121)',
#  '4 Minotaur Grunt (Set1 #137)',
#  '3 Paladin Oathbook (Set1 #140)',
#  '4 Protect (Set1 #132)',
#  '4 Rampart Protector (Set3 #111)',
#  '4 Rebuke (Set1 #141)',
#  '4 Reinforce (Set1 #136)',
#  '4 Reinvigorate (Set3 #112)',
#  "4 Rilgon's Disciple (Set4 #110)",
#  "4 Rolant's Favor (Set0 #18)",
#  '4 Shamebearer (Set4 #111)',
#  '4 Soaring Guard (Set3 #102)',
#  '4 Sparring Partner (Set2 #77)',
#  '4 Stalwart Silverwing (Set2 #72)',
#  '4 Strength of Many (Set2 #73)',
#  '4 Talon of Nostrix (Set2 #74)',
#  '4 Tinker (Set2 #75)',
#  '4 Tranquil Scholar (Set2 #76)',
#  '4 Vanquish (Set1 #143)',
#  "4 Vanquisher's Blade (Set4 #112)",
#  '4 Wanted Poster (Set3 #106)',
#  '4 Workshop Tinker (Set4 #113)',
#  '4 Auric Herdward (Set4 #114)',
#  '4 Auric Sentry (Set1 #146)',
#  '4 Brightmace Paladin (Set1 #147)',
#  '4 Copperhall Bailiff (Set1001 #5)',
#  '4 Copperhall Cudgel (Set2 #78)',
#  '4 Copperhall Marshal (Set3 #114)',
#  '4 Copperhall Shieldman (Set2 #79)',
#  '4 Crownwatch Legionnaire (Set3 #115)',
#  '4 Emerald Acolyte (Set1 #153)',
#  '4 Emerald Ring (Set2 #80)',
#  '4 Fencing Master (Set2 #81)',
#  '4 Gilded Glaive (Set1 #125)',
#  '4 Grit (Set4 #116)',
#  '4 Guard Dog (Set4 #117)',
#  '4 Herald of the Parliament (Set4 #118)',
#  '4 Hero of the People (Set1 #156)',
#  '4 Highbranch Sentry (Set2 #82)',
#  '2 Hooru Envoy (Set1 #155)',
#  '4 Kosul Battlemage (Set4 #119)',
#  '4 Longhorn Treasurer (Set4 #120)',
#  '4 Loyal Watchwing (Set1 #150)',
#  '4 Mark of Shame (Set1 #165)',
#  "4 Miner's Canary (Set4 #109)",
#  '4 Privilege of Rank (Set1 #157)',
#  '4 Reinforced Baton (Set4 #122)',
#  '4 Saddle Up (Set4 #124)',
#  '4 Showdown (Set3 #117)',
#  '4 Signal Flag (Set3 #118)',
#  '4 Silverwing Familiar (Set1 #152)',
#  '4 Silverwing Smith (Set3 #119)',
#  '1 Spirit Guide (Set2 #83)',
#  '4 Tandem Watchwing (Set3 #121)',
#  '4 Tireless Stranger (Set2 #84)',
#  '4 Treasury Guard (Set1 #505)',
#  '4 Unseen Commando (Set3 #122)',
#  '4 Valkyrie Cadet (Set3 #123)',
#  '4 Valkyrie Enforcer (Set1 #151)',
#  '4 Valorous Stranger (Set1 #145)',
#  '4 Warrant Officer (Set4 #125)',
#  '1 Winchest Merchant (Set4 #126)',
#  '4 Armorsmith (Set1 #163)',
#  '1 Auric Runehammer (Set1 #166)',
#  '4 Bronze Cuirass (Set1 #148)',
#  '2 Citywide Ban (Set4 #127)',
#  '1 Copperhall Blessing (Set1 #168)',
#  '4 Copperhall Paladin (Set1002 #7)',
#  '4 Copperhall Recruit (Set1 #158)',
#  '4 Crownwatch Cavalry (Set1 #169)',
#  '4 Curse of Taxation (Set3 #127)',
#  '4 Entrapment (Set3 #116)',
#  '4 Frontier Confessor (Set3 #137)',
#  '4 Graceful Calligrapher (Set4 #129)',
#  '4 Ground Crew (Set3 #128)',
#  '4 Honor the Fallen (Set1003 #8)',
#  '4 Ironclad Oath (Set3 #129)',
#  '4 Mantle of Justice (Set0 #21)',
#  "2 Peacekeeper's Prod (Set2 #86)",
#  '4 Rabblerouser (Set2 #87)',
#  '4 Resolute Paladin (Set4 #130)',
#  "4 Sheriff's Hat (Set4 #132)",
#  '4 Shielded Shortbarrel (Set3 #132)',
#  '4 Silverwing Avenger (Set1 #167)',
#  '4 Sky Crew (Set4 #133)',
#  '4 Spiked Buckler (Set2 #88)',
#  '4 Spiritblade Stalker (Set3 #134)',
#  '4 Stalwart Shield (Set1 #162)',
#  '4 Valkyrie Bodyguard (Set3 #135)',
#  '4 Valkyrie Militant (Set2 #89)',
#  '2 Valkyrie Spireguard (Set2 #90)',
#  "4 Victor's Cry (Set2 #91)",
#  '4 Combrei Magister (Set1 #160)',
#  '4 Crownwatch Recruiter (Set4 #134)',
#  '4 Downfall (Set4 #135)',
#  '4 Harsh Rule (Set1 #172)',
#  '4 Hooru Fledgling (Set1 #159)',
#  '4 Minotaur Duelist (Set2 #93)',
#  '4 Mithril Mace (Set1 #171)',
#  '4 Rampart Arbalest (Set4 #136)',
#  '4 Scepter of Nobility (Set2 #94)',
#  '1 Silverwing Commander (Set1 #175)',
#  '4 Throne Warden (Set1 #514)',
#  '4 Twinstrike Master (Set1002 #8)',
#  "4 Aerialist's Khopesh (Set2 #95)",
#  '1 Augmented Form (Set1 #182)',
#  '4 Ceremonial Mask (Set1 #178)',
#  '4 Civic Peacekeeper (Set1 #180)',
#  '1 End of the Story (Set4 #138)',
#  '4 Fourth-Tree Elder (Set1 #176)',
#  '4 Heirloom Blade (Set4 #139)',
#  '4 Horngrinder (Set2 #96)',
#  '1 Ironfist Archon (Set4 #140)',
#  '4 Prosecutor-at-Arms (Set2 #97)',
#  '4 Roosting Owl (Set2 #99)',
#  '4 Silverwing Purgeleader (Set4 #141)',
#  '4 Tower Shield (Set3 #144)',
#  '4 Town Watchman (Set3 #145)',
#  '4 Valkyrie Arcanist (Set3 #139)',
#  '4 Watchwing Conscript (Set1002 #9)',
#  '4 Emerald Spear (Set3 #142)',
#  '4 Flight Lieutenant (Set1 #184)',
#  "1 Rolant's Honor Guard (Set1 #183)",
#  '4 Silverwing Augmentor (Set4 #142)',
#  '1 Rolant, the Iron Fist (Set1 #185)',
#  '4 Valkyrie Linebreaker (Set2 #102)',
#  '4 Silverwing Rallier (Set3 #150)',
#  '4 Clan Standard (Set4 #145)',
#  '4 Cobalt Monument (Set1 #418)',
#  '4 Cobalt Waystone (Set3 #151)',
#  '4 Blind Storyteller (Set1 #192)',
#  '4 Cloudsnake Hatchling (Set2 #103)',
#  "4 Eilyn's Intervention (Set3 #152)",
#  '4 Farplace Finder (Set3 #153)',
#  '4 Gift of Battle (Set4 #146)',
#  '4 Hearty Stranger (Set2 #104)',
#  '4 Jump Kick (Set3 #154)',
#  '4 Permafrost (Set1 #193)',
#  '4 Savage Denial (Set4 #147)',
#  '4 Savage Skybrood (Set3 #156)',
#  '4 Shiver (Set4 #148)',
#  '4 Sinister Opportunist (Set3 #157)',
#  '1 Snow Pelting (Set3 #158)',
#  '4 Snowcrust Yeti (Set2 #105)',
#  '4 Snowrager (Set4 #149)',
#  '4 Substitute (Set4 #150)',
#  '4 Unstable Form (Set1 #189)',
#  '4 Weather the Storm (Set2 #106)',
#  '4 Yeti Spy (Set1 #191)',
#  '4 Backlash (Set1 #200)',
#  '4 Borderlands Waykeeper (Set1 #517)',
#  '4 Campfire Watchman (Set4 #151)',
#  '4 Changeestik (Set4 #152)',
#  '4 Cloudsnake Breeder (Set2 #107)',
#  '1 Cloudsnake Saddle (Set1 #199)',
#  '4 Darkbolt (Set3 #159)',
#  '4 Dragonbreath (Set2 #108)',
#  '4 Dusk Raider (Set4 #153)',
#  '4 East-Wind Herald (Set1 #201)',
#  "4 Eilyn's Favor (Set0 #24)",
#  '4 Entangling Vines (Set4 #167)',
#  '4 Fearless Yeti (Set3 #161)',
#  '4 Gruanform (Set4 #154)',
#  "4 Herald's Song (Set1 #196)",
#  '2 Honored Skyguard (Set4 #155)',
#  '4 Horizon Seeker (Set3 #162)',
#  '4 Huddle Together (Set4 #156)',
#  '4 Iceberg Hailshrieker (Set4 #157)',
#  '4 Levitate (Set1 #190)',
#  '4 Lightning Storm (Set1 #206)',
#  '4 Lightning Strike (Set1 #197)',
#  '1 Maelstrom Bell (Set2 #109)',
#  '4 Portent Reader (Set4 #159)',
#  '4 Read the Stars (Set4 #160)',
#  '4 Scaly Gruan (Set1 #215)',
#  '4 Second Sight (Set1 #207)',
#  '4 Snowfort Trumpeter (Set4 #161)',
#  '4 Static Bolt (Set1 #194)',
#  '4 Storm Talisman (Set3 #164)',
#  '4 Strategize (Set3 #165)',
#  '4 Talon Dive (Set2 #112)',
#  '4 Tend the Flock (Set4 #162)',
#  '4 Torrential Downpour (Set4 #163)',
#  '4 Trailblaze (Set2 #111)',
#  '4 Twilight Hermit (Set3 #166)',
#  '4 Unseal (Set3 #167)',
#  '4 Violent Gust (Set1 #205)',
#  '1 Whispering Wind (Set1 #202)',
#  '4 Wild Cloudsnake (Set1 #195)',
#  "4 Winter's Grasp (Set3 #168)",
#  '4 Yeti Snowchucker (Set2 #113)',
#  '4 Yeti Snowslinger (Set1 #203)',
#  '4 Yeti Windflyer (Set3 #169)',
#  '4 Acquisitive Crow (Set4 #164)',
#  '4 Advance Scout (Set4 #165)',
#  '1 Cloudsnake Harrier (Set2 #114)',
#  '4 Cobalt Acolyte (Set1 #212)',
#  '4 Cobalt Ring (Set2 #115)',
#  '4 Crafty Yeti (Set2 #116)',
#  '1 Daring Pioneer (Set3 #170)',
#  '4 Electropy (Set3 #171)',
#  '4 Flash Freeze (Set1 #209)',
#  '4 Foothills Alpha (Set2 #117)',
#  '4 Hailstorm (Set1003 #11)',
#  '4 Ice Sprite (Set1 #214)',
#  '4 Icebow (Set2 #118)',
#  '4 Icebreaker (Set1 #216)',
#  '4 Jennev Merchant (Set4 #169)',
#  '4 Lethrai Darkstalker (Set4 #170)',
#  '4 Lethrai Secretweaver (Set4 #171)',
#  '4 Mirror Image (Set1 #217)',
#  '1 Nocturnal Observer (Set3 #173)',
#  '4 Polymorph (Set1 #211)',
#  '4 Rabid Yeti (Set4 #172)',
#  '4 Skyrider Vanguard (Set2 #120)',
#  '4 Skysnapper (Set1 #208)',
#  '4 Snowfort (Set3 #174)',
#  '4 South-Wind Herald (Set1002 #10)',
#  '4 Stormcrasher (Set2 #121)',
#  '3 Temple Shihan (Set4 #173)',
#  '4 Thunderbird (Set0 #27)',
#  '4 Tundra Explorer (Set1 #204)',
#  '4 Voracious Fosora (Set3 #176)',
#  '4 Wild Rider (Set3 #177)',
#  '4 Wisdom of the Elders (Set1 #218)',
#  '2 Yeti Furflinger (Set3 #178)',
#  '1 Breeze Dancer (Set4 #174)',
#  '4 Cutbrush Cartographer (Set3 #180)',
#  '4 Freewing Glider (Set3 #181)',
#  '4 Galeprowler (Set4 #175)',
#  '4 Icespear Chucker (Set4 #176)',
#  "4 Jarrall's Frostkin (Set1 #220)",
#  '4 Jotun Cyclops (Set2 #122)',
#  '4 Meditation Trainer (Set3 #182)',
#  '4 Nocturnal Kyrex (Set3 #183)',
#  '1 Regression (Set3 #184)',
#  '4 Resurface (Set4 #177)',
#  '4 Ridgeline Watcher (Set2 #123)',
#  '4 Scavenging Spikeback (Set4 #178)',
#  '4 Serpent Mount (Set2 #124)',
#  '4 Serpent Trainer (Set1 #219)',
#  '4 Slushdumper (Set3 #185)',
#  '4 Soaring Stranger (Set1 #229)',
#  '2 Spiritward Shaman (Set4 #179)',
#  '4 Stormcaller (Set1 #224)',
#  '4 Tyrannize (Set1001 #8)',
#  '4 Windshaper (Set1 #230)',
#  '4 Yeti Troublemaker (Set1 #222)',
#  '4 Yetipult (Set1002 #11)',
#  '4 Aerial Ace (Set1 #235)',
#  "4 Aeva, Eilyn's Elite (Set4 #180)",
#  '4 Cliffside Caretaker (Set4 #186)',
#  '2 Crystallize (Set1 #232)',
#  '4 First-Frost Shaman (Set4 #182)',
#  '2 Gleaming Shield (Set4 #183)',
#  '1 Jotun Feast-Caller (Set3 #187)',
#  '4 Jotun Hurler (Set1 #227)',
#  '4 Jotun Punter (Set3 #188)',
#  '4 Jotun Warrior (Set1 #226)',
#  '4 Primal Incarnation (Set0 #30)',
#  '4 Psionic Savant (Set1 #360)',
#  '4 Skycrag Wyvarch (Set1 #247)',
#  '4 Skywalk Instructor (Set2 #128)',
#  '1 Staff of Stories (Set1 #234)',
#  '4 Stampede Driver (Set3 #190)',
#  '4 Swindle (Set2 #129)',
#  '1 West-Wind Herald (Set1 #231)',
#  '4 Boltcrafter Shaman (Set2 #131)',
#  '1 Celestial Omen (Set1 #241)',
#  "4 Cirso's Meddling (Set2 #132)",
#  '4 Daraka, Queensguard (Set1003 #12)',
#  "1 Eilyn's Frostrider (Set3 #193)",
#  '1 Hatchery Hunter (Set1 #237)',
#  '4 Iceknuckle Jotun (Set2 #133)',
#  '4 Lumbering Gruan (Set2 #134)',
#  '4 Moonlight Huntress (Set4 #188)',
#  '4 North-Wind Herald (Set1 #240)',
#  '4 Sapphire Dragon (Set1 #236)',
#  '4 Shamanic Blast (Set4 #189)',
#  '4 Slope Sergeant (Set3 #195)',
#  '4 Speardiver (Set4 #185)',
#  '2 Thunderstrike Dragon (Set1 #243)',
#  '4 Adaptive Predator (Set2 #135)',
#  '4 Araktodon (Set1 #238)',
#  '4 Bellowing Thunderfoot (Set3 #198)',
#  '4 Elysian Trailblazer (Set1 #228)',
#  '4 Enraged Araktodon (Set4 #190)',
#  '4 Hooru Teachings (Set1002 #12)',
#  '4 Icequake (Set2 #136)',
#  '1 Kenna, Shaman of the Scale (Set4 #191)',
#  '1 Mistveil Drake (Set1 #242)',
#  '1 Eilyn, Queen of the Wilds (Set1 #245)',
#  '4 Surveying Mantasaur (Set3 #199)',
#  '3 Thunder Giant (Set4 #192)',
#  '1 Channel the Tempest (Set1 #244)',
#  '4 Amethyst Monument (Set1 #426)',
#  '4 Amethyst Waystone (Set3 #201)',
#  '4 Cabal Standard (Set4 #193)',
#  '4 Affliction (Set3 #202)',
#  '4 Arachnophobia (Set3 #203)',
#  '4 Blood Beetle (Set1 #260)',
#  '4 Brash Shorthorn (Set2 #137)',
#  '4 Dark Return (Set1 #250)',
#  '4 Direfang Spider (Set1 #256)',
#  '4 Fallen Oni (Set2 #138)',
#  '4 Feral Spiteling (Set4 #205)',
#  '4 Ghostform (Set1 #258)',
#  '4 Grenamender (Set3 #204)',
#  "4 Harbinger's Bite (Set4 #194)",
#  '4 Horrifying Helm (Set4 #195)',
#  "4 Jack's Knife (Set2 #139)",
#  '4 Knifejack (Set1 #257)',
#  '4 Lock Horns (Set4 #207)',
#  '4 Pilfer (Set1 #254)',
#  '4 Sabotage (Set1 #252)',
#  '4 Sewer Sludge (Set4 #196)',
#  '4 Slumbering Stone (Set1 #255)',
#  '4 Spitefeeder (Set4 #197)',
#  '4 Suffocate (Set1 #251)',
#  '4 Swear Vengeance (Set2 #140)',
#  '4 Tock Tick (Set2 #141)',
#  '4 Trusty Revolver (Set3 #206)',
#  "4 Vara's Intervention (Set3 #207)",
#  '4 Wisplight (Set3 #208)',
#  '4 Xenan Lifespeaker (Set4 #198)',
#  '4 Abduct (Set4 #199)',
#  '4 Afterimage (Set4 #212)',
#  '4 Annihilate (Set1 #269)',
#  '4 Back-Alley Delinquent (Set4 #200)',
#  '4 Battlefield Scavenger (Set3 #209)',
#  '4 Cabal Cutthroat (Set1 #297)',
#  '4 Cabal Slasher (Set2 #147)',
#  '4 Cowardice (Set3 #211)',
#  '4 Cull the Deck (Set4 #202)',
#  '4 Dark Wisp (Set1 #264)',
#  '4 Devour (Set1 #261)',
#  '2 Dreamsnatcher (Set3 #212)',
#  '1 Fenris Nightshade (Set4 #204)',
#  '4 Flashy Duelist (Set3 #213)',
#  '4 Grenadin Bellower (Set3 #214)',
#  '4 Infused Strike (Set3 #216)',
#  '4 Lethrai Ranger (Set1 #270)',
#  '4 Lethrai Target Caller (Set4 #206)',
#  '4 Longshot Marksman (Set2 #142)',
#  '4 Lunging Wisp (Set4 #208)',
#  '4 Magenta Wisp (Set4 #209)',
#  '1 Miris Nightshade (Set3 #217)',
#  '4 Piercing Grief (Set2 #143)',
#  '4 Rapid Shot (Set1 #259)',
#  '4 Scare (Set2 #144)',
#  '4 Scavenging Vulture (Set1 #265)',
#  '4 Sleeping Draught (Set3 #218)',
#  '4 Sporefolk (Set1 #262)',
#  '4 Territorial Elf (Set4 #210)',
#  "2 Thief's Pick (Set4 #211)",
#  '4 Threaten (Set2 #145)',
#  '4 Unseen Agent (Set3 #219)',
#  '4 Vampire Bat (Set0 #33)',
#  "4 Vara's Favor (Set0 #35)",
#  '4 Venomfang Dagger (Set1 #263)',
#  '4 Amethyst Acolyte (Set1 #276)',
#  '4 Amethyst Ring (Set2 #146)',
#  '4 Auric Interrogator (Set1002 #13)',
#  '4 Banished Umbren (Set4 #213)',
#  "4 Beastcaller's Amulet (Set1 #282)",
#  '4 Blackguard Sidearm (Set1 #266)',
#  '4 Coronal Umbren (Set4 #214)',
#  '4 Daggerclaw Howler (Set4 #215)',
#  '4 Desperado (Set1 #273)',
#  '4 Devouring Shadow (Set0 #36)',
#  '4 Direwood Beastcaller (Set1 #271)',
#  '4 Duskcaller (Set3 #222)',
#  '4 Execute (Set1 #277)',
#  '4 Extract (Set2 #155)',
#  '4 Hair-Trigger Pistol (Set4 #216)',
#  '4 Kerendon Merchant (Set4 #217)',
#  '4 Lethrai Memory-Keeper (Set2 #149)',
#  '4 Lethrai Nightblade (Set1 #279)',
#  '4 Lifedrinker (Set1 #275)',
#  '4 Madness (Set1 #267)',
#  '4 Maimed Watchwing (Set3 #223)',
#  '1 Marionette Cross (Set4 #218)',
#  '4 Plague (Set1 #274)',
#  '4 Prickly Grenadin (Set3 #224)',
#  '4 Ravenous Thornbeast (Set1 #278)',
#  '4 Scheme (Set1 #213)',
#  '2 Shadowlands Guide (Set1 #280)',
#  '4 Shadowstalker (Set4 #230)',
#  '4 Skeeter (Set2 #150)',
#  "4 Sorrow's Shroud (Set2 #151)",
#  '4 Sporebreath (Set4 #219)',
#  '4 Spur On (Set2 #152)',
#  "4 Surgeon's Saw (Set4 #220)",
#  '4 Trigger-Happy (Set2 #153)',
#  '4 Umbren Deathwatcher (Set4 #221)',
#  '4 Xenan Cultist (Set1 #516)',
#  '4 Xenan Destroyer (Set1 #281)',
#  '4 Argenport Sewers (Set1003 #14)',
#  '4 Back-Alley Bouncer (Set1 #284)',
#  '4 Betray the Cause (Set4 #234)',
#  '1 Burglarize (Set4 #224)',
#  '4 Cabal Bludgeoner (Set2 #156)',
#  '4 Cabal Recruiter (Set1 #283)',
#  '4 Corrupted Umbren (Set4 #225)',
#  '4 Cripple (Set2 #157)',
#  '4 Deathstrike (Set1 #290)',
#  '1 Devious Drone (Set3 #227)',
#  '4 Extinguish (Set3 #228)',
#  '4 Final-Shot Rioter (Set3 #229)',
#  '4 Holdup (Set4 #226)',
#  '1 Impending Doom (Set1 #286)',
#  '4 In Cold Blood (Set1003 #15)',
#  '4 Kyrex Coach Driver (Set4 #227)',
#  '2 Lethrai Falchion (Set1 #285)',
#  '1 Lethrai Provocateur (Set4 #228)',
#  '2 Memory Dredger (Set2 #159)',
#  '4 Minotaur Lighthoof (Set2 #163)',
#  '1 Relentless Gorehorn (Set2 #160)',
#  '4 Savage Stranger (Set2 #161)',
#  '4 Soul Collector (Set1 #291)',
#  '1 Soulbringer (Set4 #231)',
#  '1 Steward of the Past (Set1 #287)',
#  '4 Stonescar Magus (Set1 #288)',
#  '4 Subvert (Set1 #289)',
#  '4 Transmogrifier (Set4 #232)',
#  '4 Vainglory Patrol (Set3 #231)',
#  '4 Vile Varmint (Set4 #233)',
#  '4 Xenan Fanatic (Set2 #162)',
#  '1 Ashara, the Deadshot (Set1 #295)',
#  '4 Cover of Darkness (Set3 #232)',
#  '1 Grasping at Shadows (Set1 #292)',
#  '4 Grimy Alp-luachra (Set4 #235)',
#  "4 Headsman's Axe (Set3 #233)",
#  '4 Lethrai Bladewhirl (Set4 #236)',
#  '4 Lurking Sanguar (Set1 #293)',
#  '4 Merciless Stranger (Set1 #111)',
#  '4 Moonlit Gargoyle (Set3 #234)',
#  '1 Stonescar Scrapper (Set3 #236)',
#  '4 Stray into Shadow (Set1001 #9)',
#  '2 The End is Near (Set4 #237)',
#  '4 Triggerman (Set3 #237)',
#  '4 Umbren Coaxer (Set3 #238)',
#  '4 Umbren Reaper (Set1 #299)',
#  '4 Umbren Thirster (Set2 #165)',
#  '4 Cut Ties (Set4 #238)',
#  '4 Direwood Prowler (Set2 #166)',
#  '4 Direwood Rampager (Set1 #301)',
#  '2 Dizo, Cabal Chairman (Set3 #302)',
#  '4 Drifting Death (Set3 #239)',
#  '4 Finback Komonat (Set3 #240)',
#  '4 Gunrustler (Set3 #241)',
#  '4 Horsesnatcher Bat (Set1 #304)',
#  '4 Spirit Drain (Set1 #302)',
#  "1 Azindel's Gift (Set1 #306)",
#  '4 Cabal Rogue (Set2 #168)',
#  '1 Dangerous Bargain (Set3 #245)',
#  '4 Inspire Obedience (Set2 #169)',
#  '4 Repulsive Gorger (Set3 #246)',
#  '4 Shadowlands Feaster (Set1001 #10)',
#  '1 Vara, Fate-Touched (Set1 #307)',
#  '4 Praxis Banner (Set2 #171)',
#  '4 Seat of Impulse (Set0 #54)',
#  '4 Alluring Ember (Set2 #172)',
#  '4 Noble Firemane (Set2 #174)',
#  '4 Purify (Set2 #176)',
#  '4 Waker of Ancients (Set1002 #16)',
#  '4 Journeyman Armorer (Set2 #175)',
#  '4 Magus of Celerity (Set4 #241)',
#  '1 Mysterium Orb (Set3 #252)',
#  '4 Brilliant Discovery (Set2 #177)',
#  '4 Monolith Guardian (Set3 #253)',
#  '4 Recombobulate (Set4 #242)',
#  '4 Sandglass Juggernaut (Set1003 #16)',
#  '2 Shatterglass Mage (Set2 #181)',
#  "4 Talir's Choice (Set2 #180)",
#  '1 Workshop Forge (Set2 #182)',
#  '4 Sandglass Sentinel (Set2 #184)',
#  '2 Crest of Glory (Set4 #243)',
#  '4 Rakano Banner (Set1 #427)',
#  '4 Seat of Glory (Set0 #56)',
#  '2 Bulletshaper (Set4 #244)',
#  '4 Champion of Glory (Set1 #314)',
#  "4 Ijin's Choice (Set4 #245)",
#  '4 Crownwatch Deserter (Set1 #316)',
#  '4 Sower of Dissent (Set1003 #17)',
#  '4 Sword of Icaria (Set1 #315)',
#  '4 Whirling Duo (Set3 #254)',
#  '4 Battleblur Centaur (Set1 #319)',
#  '4 Longhorn Sergeant (Set1 #318)',
#  '4 Renegade Valkyrie (Set1 #321)',
#  '1 Righteous Fury (Set1 #322)',
#  '4 Field Captain (Set1 #324)',
#  '4 Jekk, the Bounty Hunter (Set1001 #11)',
#  '1 Icaria, the Liberator (Set1 #329)',
#  '4 Combrei Banner (Set1 #424)',
#  '2 Crest of Progress (Set4 #247)',
#  '4 Seat of Progress (Set0 #58)',
#  '2 Alessi, Combrei Archmage (Set4 #248)',
#  '4 Awakened Student (Set1 #331)',
#  '4 Desert Marshal (Set1 #332)',
#  '4 Jaril, Amaran Ghostblade (Set1003 #20)',
#  '4 Safe Return (Set1 #330)',
#  '4 Auric Record Keeper (Set3 #258)',
#  '4 Combrei Emissary (Set1001 #12)',
#  '4 Combrei Healer (Set1 #333)',
#  '1 Shush (Set3 #259)',
#  '2 Stand Together (Set1 #334)',
#  "1 Vodakhan's Staff (Set1 #336)",
#  '2 Copperhall Elite (Set1 #340)',
#  '4 Genetrix Irel IV (Set4 #307)',
#  '4 Karmic Guardian (Set1 #341)',
#  '2 Sword of Unity (Set4 #249)',
#  '1 The Great Parliament (Set1 #338)',
#  "2 Stronghold's Visage (Set1 #339)",
#  '1 Champion of Progress (Set1 #345)',
#  '4 Minotaur Ambassador (Set1 #346)',
#  "4 Siraf's Choice (Set4 #250)",
#  '4 Elysian Banner (Set1 #421)',
#  '4 Seat of Wisdom (Set0 #63)',
#  '1 Derry Cathain, Ripclaw Rider (Set4 #251)',
#  '4 Storm Lynx (Set1 #353)',
#  '4 Twinning Ritual (Set1 #79)',
#  '4 Amaran Camel (Set1 #357)',
#  '4 False Prince (Set1 #356)',
#  '4 Pteriax Hatchling (Set1 #354)',
#  '4 Avisaur Patriarch (Set1001 #13)',
#  '1 Champion of Wisdom (Set1 #358)',
#  "4 Cirso's Choice (Set4 #252)",
#  '4 Nesting Avisaur (Set1 #225)',
#  '4 Scaletender (Set3 #260)',
#  '2 Hunting Pteriax (Set1 #363)',
#  '2 Crest of Order (Set4 #253)',
#  '4 Hooru Banner (Set2 #216)',
#  '4 Seat of Order (Set0 #51)',
#  '4 Bring Down (Set2 #217)',
#  "4 Linebreaker's Shield (Set4 #254)",
#  '4 Vision of Austerity (Set1002 #17)',
#  '4 Aerialist Trainer (Set2 #219)',
#  "4 Eilyn's Choice (Set2 #220)",
#  '4 Hooru Pacifier (Set1003 #23)',
#  '4 Spellshield Architect (Set2 #221)',
#  '4 Long Live the Queen (Set4 #255)',
#  '2 Shelterwing Rider (Set2 #223)',
#  '4 Shield Bash (Set2 #224)',
#  '1 Champion of Order (Set2 #225)',
#  '4 Deepwood Ranger (Set3 #262)',
#  "4 Duelist's Blade (Set2 #226)",
#  '4 Highwind Glider (Set2 #227)',
#  '1 Meditative Stranger (Set2 #228)',
#  '4 Argenport Banner (Set2 #231)',
#  '4 Crest of Vengeance (Set3 #264)',
#  '4 Seat of Vengeance (Set0 #55)',
#  '4 Anointer of the Faithful (Set1003 #24)',
#  '4 Auric Bully (Set2 #232)',
#  "2 Inquisitor's Halberd (Set3 #273)",
#  '4 Rooftop Vigilante (Set3 #274)',
#  '4 Slay (Set2 #236)',
#  '4 Stonepowder Alchemist (Set2 #239)',
#  '1 Unfinished Business (Set4 #256)',
#  '4 Sanguine Sword (Set2 #238)',
#  '4 Streetwise Informant (Set2 #240)',
#  '4 Knight of Sorrow (Set4 #257)',
#  "4 Rolant's Choice (Set2 #243)",
#  '4 Tavrod, Auric Broker (Set1002 #18)',
#  '4 Valkyrie Denouncer (Set2 #244)',
#  '2 Crest of Fury (Set3 #266)',
#  '4 Seat of Fury (Set0 #53)',
#  '4 Skycrag Banner (Set2 #186)',
#  '4 Champion of Fury (Set2 #187)',
#  "4 Kaleb's Choice (Set2 #188)",
#  '4 Rockslide (Set2 #189)',
#  '4 Clan Hero (Set2 #190)',
#  '3 Crunch, the Hoarder (Set4 #258)',
#  '4 Pokpok, Rockpacker (Set1003 #18)',
#  "4 Hunter's Harpoon (Set2 #193)",
#  '4 Mortar (Set2 #194)',
#  '4 Storm Glider (Set2 #195)',
#  '4 Unexpected Results (Set1002 #19)',
#  '4 Bloodthirsty Brawler (Set4 #259)',
#  '4 Iceberg Warchief (Set3 #257)',
#  '2 Tamarys, the Geomancer (Set4 #308)',
#  '1 Towering Stranger (Set2 #196)',
#  '4 Topaz Drake (Set2 #198)',
#  '4 Crest of Cunning (Set3 #267)',
#  '4 Feln Banner (Set1 #417)',
#  '4 Seat of Cunning (Set0 #62)',
#  '4 Twilight Raptor (Set1 #379)',
#  '4 Gorgon Swiftblade (Set1 #377)',
#  '1 Grim Stranger (Set1 #372)',
#  '4 Haunting Scream (Set1 #374)',
#  "4 Rindra's Choice (Set4 #261)",
#  '1 Feln Bloodcaster (Set1 #386)',
#  '4 Gorgon Fanatic (Set1 #375)',
#  '4 Skywalk Enforcer (Set3 #276)',
#  "4 Trickster's Cloak (Set1 #369)",
#  '4 Ancient of the Ice Caves (Set4 #262)',
#  '4 Cabal Spymaster (Set1001 #14)',
#  '4 Feeding Time (Set1 #381)',
#  '4 Lethrai Skystrider (Set1003 #25)',
#  '1 Champion of Cunning (Set1 #371)',
#  '2 Spell Swipe (Set1 #373)',
#  '2 Withering Witch (Set1 #368)',
#  '2 Crest of Chaos (Set3 #268)',
#  '4 Seat of Chaos (Set0 #60)',
#  '4 Stonescar Banner (Set1 #419)',
#  '4 Combust (Set1 #392)',
#  '1 Hair-Trigger Stranger (Set1 #253)',
#  '4 Obsidian Golem (Set1 #398)',
#  '4 Treachery (Set1 #394)',
#  '4 Wyatt, Junk Collector (Set4 #306)',
#  '1 Champion of Chaos (Set1 #402)',
#  '4 Recycler (Set3 #269)',
#  '4 Stonescar Pickaxe (Set4 #263)',
#  "4 Jekk's Choice (Set4 #264)",
#  '4 Runic Revolver (Set1 #404)',
#  '4 Warband Chieftain (Set1 #395)',
#  '2 Failed Reflection (Set3 #270)',
#  '3 Infernal Tyrant (Set1 #390)',
#  "4 Smuggler's Stash (Set1 #396)",
#  '4 Crest of Mystery (Set4 #266)',
#  '4 Seat of Mystery (Set0 #61)',
#  '4 Xenan Banner (Set2 #201)',
#  '4 Bloodcall Invocation (Set2 #203)',
#  '4 Blistersting Wasp (Set2 #202)',
#  '4 Mitotic Wisp (Set1003 #22)',
#  "4 Vara's Choice (Set2 #206)",
#  '1 Ayan, the Abductor (Set2 #204)',
#  '4 Shadowlands Bonepicker (Set2 #205)',
#  '4 Duskwalker (Set3 #271)',
#  '4 Katra, the Devoted (Set2 #208)',
#  '4 Preserver of Dualities (Set4 #267)',
#  '4 Xenan Augury (Set2 #209)',
#  '4 Xenan Cupbearer (Set2 #210)',
#  '4 Bloodcall Invoker (Set2 #211)',
#  '1 Champion of Mystery (Set2 #213)',
#  '1 Prophetic Stranger (Set2 #214)',
#  "1 Cirso's Cleaver (Set4 #270)",
#  '4 Triumphant Stranger (Set1002 #21)',
#  '1 Nictotraxian (Set1001 #16)',
#  "4 Chairman's Contract (Set4 #271)",
#  '4 Common Cause (Set3 #279)',
#  '4 Diplomatic Seal (Set1 #425)',
#  '4 Spiked Helm (Set1 #406)',
#  "4 Alchemist's Concoction (Set4 #272)",
#  '4 Family Charter (Set3 #280)',
#  '4 Horus Traver (Set1002 #23)',
#  '4 Seek Power (Set1 #408)',
#  '4 Veteran Strategist (Set4 #273)',
#  ...]

# %%
"""
 For initial pass, this cell will count the cards we have to make the deck already, and count the total cards in the deck.\
 Then it will output the percentage we have, and what were missing. :)
"""
for current_deck in decks_clean:
    # Remove market delimiter *card* for now. Unecessary.
    if '--------------MARKET---------------' in current_deck: current_deck.remove('--------------MARKET---------------')
    user_count = 0
    deck_count = 0
    cards_missing = []
    # For each card in this deck instance.
    for current_card in current_deck:
        found_card = False
        # Split deck's current card into count and name.
        deck_card = current_card.split(" ",1)  # The 1 indicates split on the FIRST space only.

        # Check if the deck card is in our collection.
        for card in collection['my_collection']:
            if deck_card[1] in card:
                # WE HAVE THE CARD! Now how many?
                found_card = True # Set flag to NOT add to missing list.
                temp_user_card = card.split(" ",1)  # This holds the count of THAT card that we have in our collection.
                # Below we deduce if we have all the cards, less, or more than needed for the deck.
                if temp_user_card[0] == deck_card[0]:
                    # This means we need 4, we have 4 (4-4)
                    x = temp_user_card[0]
                elif (int(temp_user_card[0]) - int(deck_card[0])) > 0:
                    # This means, for example, we have 4 of a specific card and the deck only requires 2.
                    x = deck_card[0]
                else:
                    # This means we have LESS of a specific card than the amount we need...
                    x = temp_user_card[0]
                    # Give amount were missing and the card. Append to missing_cards.
                    amount_missing_card = str(int(deck_card[0]) - int(temp_user_card[0])) + " " + deck_card[1]
                    cards_missing.append(amount_missing_card)
                # Add the cards we do have to our user_count. Also make sure we don't add more than deck has! (ie deck has 2, we have 4)
                user_count = user_count + int(x)
                
                
        if not found_card and 'Sigil' not in current_card:
            # We DON'T have the card at all! Add it to our missing cards list.
            cards_missing.append(current_card)
        # No matter what add the count to deck_count!
        deck_count = deck_count + int(deck_card[0])
        
        
    similarity_prob = (float(user_count)/float(deck_count)) * 100
    print('You own: ' + str(round(similarity_prob, 2)) + '% of the deck. Your missing these cards:')
    print(cards_missing)
    print('')
# Out:
# You own: 56.25% of the deck. Your missing these cards:
# ['2 Banish (Set2 #207)', '1 Crest of Wisdom (Set3 #261)', '4 Teacher of Humility (Set4 #67)', '4 Cykalis, the Burning Sand (Set5 #57)', '4 Kerendon Steward (Set5 #159)', "4 Torgov's Trading Post (Set5 #203)", '4 Equivocate (Set1003 #21)', '4 Shakedown (Set1004 #18)', '1 Accelerated Evolution (Set1 #351)']
#
# You own: 63.75% of the deck. Your missing these cards:
# ['4 Hojan, Crownbreaker (Set5 #86)', '4 Avigraft (Set5 #95)', '4 Highland Sharpshooter (Set5 #197)', '4 Red Canyon Smuggler (Set5 #198)', '1 Obliterate (Set1 #48)', '1 Deepforged Plate (Set1 #317)']
#
# You own: 46.25% of the deck. Your missing these cards:
# ['3 Sandstorm Titan (Set1 #99)', '4 Heart of the Vault (Set2 #183)', '2 Crest of Fury (Set3 #266)', '1 Crest of Impulse (Set3 #251)', '4 Crest of Wisdom (Set3 #261)', '2 Jotun Feast-Caller (Set3 #187)', '3 Jennev Cargo (Set5 #242)', '3 Display of Instinct (Set5 #244)', '3 Zal Chi, Herald of War (Set5 #245)', '3 Howling Peak (Set5 #219)', '4 Equivocate (Set1003 #21)', '1 Jennev Cargo (Set5 #242)', '1 Zal Chi, Herald of War (Set5 #245)', '1 Howling Peak (Set5 #219)']
#
# You own: 55.0% of the deck. Your missing these cards:
# ['4 Argenport Instigator (Set1 #268)', '2 Midnight Gale (Set1 #378)', '4 Cabal Countess (Set1 #506)', '1 Fenris Nightshade (Set4 #204)', '2 Frostwave (Set5 #114)', '4 Parry (Set5 #123)', '4 Ripknife Assassin (Set1003 #13)', '4 Shakedown (Set1004 #18)', '1 Vara, Vengeance-Seeker (Set1004 #19)']
#
# You own: 33.75% of the deck. Your missing these cards:
# ['2 Crest of Chaos (Set3 #268)', '2 Bulletshaper (Set4 #244)', '2 Crest of Glory (Set4 #243)', '4 Rizahn, Greatbow Master (Set4 #246)', '4 Xo of the Endless Hoard (Set5 #36)', '4 Red Canyon Smuggler (Set5 #198)', '4 Lost Scroll (Set5 #208)', '4 Hidden Road Smuggler (Set5 #210)', '4 Winchest Cargo (Set5 #237)', '4 Display of Ambition (Set5 #239)', '4 Quarry (Set1001 #15)', '2 Vara, Vengeance-Seeker (Set1004 #19)', '1 Statuary Maiden (Set1 #387)', "1 Martyr's Chains (Set5 #110)", "1 Regent's Tomb (Set5 #213)", '1 Bore (Set1003 #1)']
#
# You own: 36.25% of the deck. Your missing these cards:
# ['1 Auric Runehammer (Set1 #166)', '4 Defiance (Set5 #77)', '4 Hojan, Crownbreaker (Set5 #86)', '3 Avigraft (Set5 #95)', "4 Rhysta, Acantha's Herald (Set5 #168)", '4 Lost Scroll (Set5 #208)', '4 Hidden Road Smuggler (Set5 #210)', "4 Telut, Queen's Hand (Set1004 #12)", '2 Unwavering Exorcist (Set1004 #9)', '4 Vara, Vengeance-Seeker (Set1004 #19)', '1 Devastating Setback (Set3 #226)', '1 Amilli, Cloudmarshal (Set3 #136)', "1 Martyr's Chains (Set5 #110)", "1 Regent's Tomb (Set5 #213)"]

# %%
# Success! First run we simply wanted a percentage of the cards we already have for a deck, next step would be calculating 
# the CHEAPEST decks to finish creating (ie: some cards are legendary, thus cost a LOT more to craft with shifstone)
